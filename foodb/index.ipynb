# %% [markdown]
# # FooDB.ca Data Analysis

# %% [markdown]
# <a id = 'top'></a>

# %% [markdown]
# # Contents
#
# - [Libraries and Functions]
# - [Exploratory Data Analysis](#eda)
#  - [Foods](#eda_foods)
#  - [Enzymes](#eda_enzymes)
#  - [Flavors](#eda_flavors)
#  - [Health effects](#eda_health_effects)
#  - [Nutrients](#eda_nutrients) (Dropped)
#  - [Pathways](#eda_pathways)
#  - [References](#eda_ref) (Dropped)
#  - [Food taxonomies](#eda_food_tax)
#  - [Compounds](#eda_compounds)
# - [Dropping columns](#droppingcolumns)
#  - [Foods](#dropcol_foods)
#  - [Enzymes](#dropcol_enzymes)
#  - [Flavors](#dropcol_flavors)
#  - [Health effects](#dropcol_health_effects)
#  - [Pathways](#dropcol_pathways)
#  - [Food taxonomies](#dropcol_food_tax)
#    - [Test query of morels](#test_query_ft)
#  - [Compounds](#dropcol_compounds)
# - [Dropping whole tables](#dropping_tables)

# %% [markdown]
# # Libraries and Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
#For the ORM:
import sqlalchemy
from sqlalchemy import create_engine #To connect to the database
from sqlalchemy.orm import Session, sessionmaker #To interact with the database as object
from sqlalchemy import inspect #To look at tables and column names

# %%
#import plotly.plotly as py
#import plotly.figure_factory as ff

# %%
#needs plotly password
#df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

#table = ff.create_table(df)
#py.iplot(table, filename='jupyter-table1')

# %%
#Instantiate a session of the ORM
#Connect to the sqlite database file
engine = create_engine('sqlite:///foodb.db', echo = True)
#Bind a session factory to the engine
Session = sessionmaker(bind=engine)
#Instantiate a session
session = Session()

# %%
#An object to get a first look at the database
inspector = inspect(engine)
# Out:
# 2019-03-17 09:22:55,781 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-03-17 09:22:55,781 INFO sqlalchemy.engine.base.Engine ()
# 2019-03-17 09:22:55,781 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-03-17 09:22:55,793 INFO sqlalchemy.engine.base.Engine ()

# %%
#Make a dict of list of names of all the columns in all the tables
#for easy reference

#Get list of all table names
table_names = inspector.get_table_names()

table_columns = dict()
#For each table name
for table in table_names:
    column_names = []
    #for each column in the table, get just the name
    for column in inspector.get_columns(table):
        column_names.append(column['name'])
    table_columns[table] = column_names

# %%
def get_value_from_cols(table, value):
    for column in table.columns:
        print(column, table[table[column] == value].shape[0])

# %% [markdown]
# <a id = 'eda'></a>

# %% [markdown]
# [(Back to top)](#top)
#
# # Exploratory Data Analysis

# %% [markdown]
# ## Trying to find the link from foods to compounds

# %%
table_names
# Out:
# ['compound_alternate_parents',
#  'compound_external_descriptors',
#  'compound_substituents',
#  'compound_synonyms',
#  'compounds',
#  'compounds_enzymes',
#  'compounds_flavors',
#  'compounds_health_effects',
#  'compounds_pathways',
#  'enzymes',
#  'flavors',
#  'food_taxonomies',
#  'foodcomex_compound_providers',
#  'foodcomex_compounds',
#  'foods',
#  'health_effects',
#  'nutrients',
#  'pathways',
#  'references']

# %% [markdown]
# <a id = 'eda_foods'></a>

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
compounds = pd.read_sql_query('''SELECT c.* 
                                FROM compounds c
                                ;''', engine)
references = pd.read_sql_query('''SELECT r.* 
                                FROM [references] r
                                ;''', engine)
nutrients = pd.read_sql_query('''SELECT n.* 
                                FROM nutrients n
                                ;''', engine)
# Out:
# 2019-03-17 09:25:21,500 INFO sqlalchemy.engine.base.Engine SELECT c.*
#                                 FROM compounds c
#                                 ;
# 2019-03-17 09:25:21,500 INFO sqlalchemy.engine.base.Engine ()
# 2019-03-17 09:25:22,912 INFO sqlalchemy.engine.base.Engine SELECT r.*
#                                 FROM [references] r
#                                 ;
# 2019-03-17 09:25:22,914 INFO sqlalchemy.engine.base.Engine ()
# 2019-03-17 09:25:23,130 INFO sqlalchemy.engine.base.Engine SELECT n.*
#                                 FROM nutrients n
#                                 ;
# 2019-03-17 09:25:23,131 INFO sqlalchemy.engine.base.Engine ()

# %%
compounds.head()
# Out:
#    id legacy_id                   type  public_id  \
# 0   1         1  SmallMoleculeCompound  FDB000001
# 1   4         4  SmallMoleculeCompound  FDB000004
# 2  13        22  SmallMoleculeCompound  FDB000013
# 3  14        23  SmallMoleculeCompound  FDB000014
# 4  22        36  SmallMoleculeCompound  FDB000022
#
#                                       name export   state annotation_quality  \
# 0                          Mulberrofuran P   TRUE                        low
# 1      Cyanidin 3-(6''-acetyl-galactoside)   TRUE                        low
# 2      Cyanidin 3-(6''-succinyl-glucoside)   TRUE                        low
# 3  Pelargonidin 3-(6''-succinyl-glucoside)   TRUE  liquid                low
# 4    Cyanidin 3-O-(6''-acetyl-arabinoside)   TRUE                        low
#
#                                          description   cas_number     ...      \
# 0      Constit. of Morus alba (white mulberry) [CCD]  101365-02-0     ...
# 1      Constit. of the leaves of Nymphaea alba [CCD]  350602-26-5     ...
# 2             Constit. of Phragmites australis [CCD]  216692-08-9     ...
# 3                                                                     ...
# 4  A polyphenol compound found in foods of plant ...                  ...
#
#                          superklass                        klass  \
# 0  Phenylpropanoids and polyketides  2-arylbenzofuran flavonoids
# 1  Phenylpropanoids and polyketides                   Flavonoids
# 2  Phenylpropanoids and polyketides                   Flavonoids
# 3
# 4  Phenylpropanoids and polyketides                   Flavonoids
#
#                subklass                 direct_parent  \
# 0                         2-arylbenzofuran flavonoids
# 1  Flavonoid glycosides  Anthocyanidin-3-O-glycosides
# 2  Flavonoid glycosides  Anthocyanidin-3-O-glycosides
# 3
# 4  Flavonoid glycosides  Anthocyanidin-3-O-glycosides
#
#                    molecular_framework chembl_id chemspider_id meta_cyc_id  \
# 0  Aromatic heteropolycyclic compounds
# 1  Aromatic heteropolycyclic compounds
# 2  Aromatic heteropolycyclic compounds
# 3
# 4  Aromatic heteropolycyclic compounds
#
#   foodcomex phytohub_id
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 106 columns]

# %%
compounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28771 entries, 0 to 28770
# Columns: 106 entries, id to phytohub_id
# dtypes: object(106)
# memory usage: 23.3+ MB

# %%
get_value_from_cols(compounds, '')
# Out:
# id 0
# legacy_id 9440
# type 0
# public_id 0
# name 0
# export 0
# state 19602
# annotation_quality 1300
# description 5479
# cas_number 10558
# melting_point 21845
# protein_formula 28771
# protein_weight 28771
# experimental_solubility 27885
# experimental_logp 27881
# hydrophobicity 28771
# isoelectric_point 28771
# metabolism 28770
# kegg_compound_id 22120
# pubchem_compound_id 10917
# pubchem_substance_id 28766
# chebi_id 26241
# het_id 27797
# uniprot_id 28771
# uniprot_name 28771
# genbank_id 28771
# wikipedia_id 24269
# synthesis_citations 28771
# general_citations 28600
# comments 28295
# protein_structure_file_name 28771
# protein_structure_content_type 28771
# protein_structure_file_size 28771
# protein_structure_updated_at 28771
# msds_file_name 27318
# msds_content_type 27318
# msds_file_size 27318
# msds_updated_at 27318
# creator_id 28695
# updater_id 22203
# created_at 0
# updated_at 0
# phenolexplorer_id 27994
# dfc_id 13712
# hmdb_id 8011
# duke_id 22578
# drugbank_id 28078
# bigg_id 27895
# eafus_id 25821
# knapsack_id 23957
# boiling_point 26467
# boiling_point_reference 26554
# charge 28707
# charge_reference 28771
# density 27998
# density_reference 27998
# optical_rotation 23620
# optical_rotation_reference 23620
# percent_composition 14728
# percent_composition_reference 14728
# physical_description 28646
# physical_description_reference 28646
# refractive_index 27913
# refractive_index_reference 27913
# uv_index 26704
# uv_index_reference 26704
# experimental_pka 28239
# experimental_pka_reference 28429
# experimental_solubility_reference 27919
# experimental_logp_reference 27907
# hydrophobicity_reference 28771
# isoelectric_point_reference 28771
# melting_point_reference 22498
# moldb_alogps_logp 5240
# moldb_logp 4370
# moldb_alogps_logs 5240
# moldb_smiles 2281
# moldb_pka 15738
# moldb_formula 2277
# moldb_average_mass 2277
# moldb_inchi 2276
# moldb_mono_mass 2277
# moldb_inchikey 2276
# moldb_alogps_solubility 5240
# moldb_id 4372
# moldb_iupac 4374
# structure_source 4311
# duplicate_id 28684
# old_dfc_id 28552
# dfc_name 13995
# compound_source 0
# flavornet_id 28040
# goodscent_id 26173
# superscent_id 28354
# phenolexplorer_metabolite_id 28399
# kingdom 23506
# superklass 23506
# klass 23546
# subklass 24105
# direct_parent 23506
# molecular_framework 23512
# chembl_id 25951
# chemspider_id 14008
# meta_cyc_id 24150
# foodcomex 27726
# phytohub_id 28771

# %%
phenolexplorer_id 27994
dfc_id 13712
hmdb_id 8011
duke_id 22578
drugbank_id 28078
bigg_id 27895
eafus_id 25821
knapsack_id 23957
flavornet_id 28040
goodscent_id 26173
superscent_id 28354

# %%
compounds['kegg_compound_id'].value_counts()[:5]
# Out:
#           22120
# C00350      960
# C00157      956
# C00626      378
# C00422      119
# Name: kegg_compound_id, dtype: int64

# %%
compounds['structure_source'].value_counts()
# Out:
# HMDB_from_dfc          8463
# HMDB                   7723
# DFC                    4504
#                        4311
# MANUAL                 2285
# BIOSPIDER               991
# HMDB_from_biospider     284
# MANUAL_from_darndt      165
# FOODCOMEX                24
# DataWrangler             21
# Name: structure_source, dtype: int64

# %% [markdown]
# Could structure source be helpful here? Maybe workign together with the various id columns?

# %%
compounds['compound_source'].value_counts()
# Out:
# DFC               14733
# HMDB               7765
# DUKE               3108
# MANUAL             1279
# EAFUS               819
# KNAPSACK            466
# PHENOLEXPLORER      404
# FLAVORNET           140
# FOODCOMEX            24
# SUPERSCENT           19
# OTHER                10
# TABLES                4
# Name: compound_source, dtype: int64

# %%
compounds[compounds['dfc_id'] != '']
# Out:
#           id legacy_id                   type  public_id  \
# 0          1         1  SmallMoleculeCompound  FDB000001
# 1          4         4  SmallMoleculeCompound  FDB000004
# 2         13        22  SmallMoleculeCompound  FDB000013
# 13        52        69  SmallMoleculeCompound  FDB000052
# 15        59        76  SmallMoleculeCompound  FDB000059
# 25        78        95  SmallMoleculeCompound  FDB000078
# 32        86       107  SmallMoleculeCompound  FDB000086
# 33        87       108  SmallMoleculeCompound  FDB000087
# 67       173       295  SmallMoleculeCompound  FDB000173
# 68       176       299  SmallMoleculeCompound  FDB000176
# 70       180       304  SmallMoleculeCompound  FDB000180
# 73       183       307  SmallMoleculeCompound  FDB000183
# 78       189       314  SmallMoleculeCompound  FDB000189
# 96       229       396  SmallMoleculeCompound  FDB000229
# 121      263       460  SmallMoleculeCompound  FDB000263
# 122      264       461  SmallMoleculeCompound  FDB000264
# 126      271       469  SmallMoleculeCompound  FDB000271
# 127      272       470  SmallMoleculeCompound  FDB000272
# 151      298       503  SmallMoleculeCompound  FDB000298
# 152      299       504  SmallMoleculeCompound  FDB000299
# 153      301       506  SmallMoleculeCompound  FDB000301
# 154      302       507  SmallMoleculeCompound  FDB000302
# 173      330       571  SmallMoleculeCompound  FDB000330
# 197      359       677  SmallMoleculeCompound  FDB000359
# 199      361       680  SmallMoleculeCompound  FDB000361
# 200      362       687  SmallMoleculeCompound  FDB000362
# 201      363       700  SmallMoleculeCompound  FDB000363
# 202      364       706  SmallMoleculeCompound  FDB000364
# 203      365       707  SmallMoleculeCompound  FDB000365
# 204      366       709  SmallMoleculeCompound  FDB000366
# ...      ...       ...                    ...        ...
# 19432  22089            SmallMoleculeCompound  FDB021926
# 19612  22269            SmallMoleculeCompound  FDB022106
# 19650  22308            SmallMoleculeCompound  FDB022145
# 19654  22312            SmallMoleculeCompound  FDB022149
# 19676  22334            SmallMoleculeCompound  FDB022171
# 19723  22381            SmallMoleculeCompound  FDB022218
# 19734  22392            SmallMoleculeCompound  FDB022229
# 19741  22399            SmallMoleculeCompound  FDB022236
# 19907  22567            SmallMoleculeCompound  FDB022404
# 19965  22626            SmallMoleculeCompound  FDB022463
# 20169  22831            SmallMoleculeCompound  FDB022668
# 20201  22863            SmallMoleculeCompound  FDB022700
# 20295  22957            SmallMoleculeCompound  FDB022794
# 20319  22981            SmallMoleculeCompound  FDB022818
# 20436  23100            SmallMoleculeCompound  FDB022937
# 20569  23235            SmallMoleculeCompound  FDB023072
# 20628  23296            SmallMoleculeCompound  FDB023133
# 20655  23324            SmallMoleculeCompound  FDB023161
# 20778  23447            SmallMoleculeCompound  FDB023284
# 21073  23744            SmallMoleculeCompound  FDB023581
# 21286  23959            SmallMoleculeCompound  FDB023796
# 21327  24001            SmallMoleculeCompound  FDB023838
# 25353  28031            SmallMoleculeCompound  FDB027868
# 25814  28494            SmallMoleculeCompound  FDB028331
# 25901  28582            SmallMoleculeCompound  FDB028419
# 27141  29830            SmallMoleculeCompound  FDB029667
# 27264  29955            SmallMoleculeCompound  FDB029792
# 27394  30091            SmallMoleculeCompound  FDB029928
# 27442  30143            SmallMoleculeCompound  FDB029980
# 27470  30171            SmallMoleculeCompound  FDB030008
#
#                                                     name export   state  \
# 0                                        Mulberrofuran P   TRUE
# 1                    Cyanidin 3-(6''-acetyl-galactoside)   TRUE
# 2                    Cyanidin 3-(6''-succinyl-glucoside)   TRUE
# 13                                             Pinotin A   TRUE
# 15                    Peonidin 3-(6''-malonyl-glucoside)   TRUE
# 25                                          Luteolinidin   TRUE
# 32                     3-Hydroxyphloretin 2'-O-glucoside   TRUE
# 33                                    3-Hydroxyphloretin   TRUE
# 67                         Quercetin 3,4',7-triglucoside   TRUE
# 68                                 3,7-Dimethylquercetin   TRUE
# 70            Kaempferol 3-sophorotrioside 7-sophoroside   TRUE
# 73                  Kaempferol 3-feruloylsophorotrioside  FALSE
# 78     Quercetin 3-O-(6"-malonyl-glucoside) 7-O-gluco...   TRUE
# 96                               Gallic acid 3-O-gallate   TRUE
# 121                           5-5'-Dehydrodiferulic acid   TRUE
# 122                           5-8'-Dehydrodiferulic acid   TRUE
# 126                           8-4'-Dehydrodiferulic acid   TRUE
# 127                           8-8'-Dehydrodiferulic acid   TRUE
# 151                               Caffeoyl aspartic acid   TRUE
# 152                            p-Coumaroyl aspartic acid   TRUE   Solid
# 153                                    Caffeoyl tyrosine   TRUE   Solid
# 154                        p-Coumaroyl 3-hydroxytyrosine   TRUE
# 173                                         Todolactol A   TRUE
# 197                               3'-Methoxyacetophenone   TRUE  liquid
# 199                                           Nuatigenin   TRUE
# 200                                            Estradiol   TRUE   Solid
# 201              4',7-Dihydroxy-2',5-dimethoxyisoflavone   TRUE
# 202                              Hexamethylquercetagetin   TRUE
# 203    Diosgenin 3-[glucosyl-(1->4)-rhamnosyl-(1->4)-...   TRUE
# 204                                              Dioscin   TRUE
# ...                                                  ...    ...     ...
# 19432                                    L-Phosphoserine   TRUE   Solid
# 19612                              4-Phenylbutanoic acid   TRUE   Solid
# 19650                             D-Ribulose 5-phosphate   TRUE   Solid
# 19654                                      D-Leucic acid   TRUE   Solid
# 19676                                     DL-Leucic acid   TRUE   Solid
# 19723                                      L-Leucic acid   TRUE   Solid
# 19734                                     Hyocholic acid   TRUE   Solid
# 19741                                  Phenyllactic acid   TRUE   Solid
# 19907                            2-Hydroxyphenethylamine   TRUE   Solid
# 19965                                        Lathosterol   TRUE   Solid
# 20169                                        Glucosamine   TRUE   Solid
# 20201                                 DL-O-Phosphoserine   TRUE   Solid
# 20295                                      Ubiquinone Q1   TRUE   Solid
# 20319                          L,L-Cyclo(histidylprolyl)   TRUE   Solid
# 20436  7,7',8,8',11,11',12,12'-Hexahydro-psi,psi-Caro...   TRUE   Solid
# 20569                               Testosterone sulfate   TRUE   Solid
# 20628                                    Dihydrocortisol   TRUE   Solid
# 20655                             2-Phosphoglyceric acid   TRUE   Solid
# 20778                         11beta-Hydroxyprogesterone   TRUE   Solid
# 21073                                       Lansoprazole   TRUE   Solid
# 21286                    20-Hydroxyeicosatetraenoic acid   TRUE   Solid
# 21327                                 D-Propylene glycol   TRUE   Solid
# 25353                         (R)-3-Hydroxyhexanoic acid   TRUE   Solid
# 25814                                           L-Iditol   TRUE   Solid
# 25901                             N-Acetyl-D-mannosamine   TRUE   Solid
# 27141                                      alpha-Ocimene   TRUE
# 27264                                      Menatetrenone   TRUE
# 27394                                         Melanettin   TRUE   Solid
# 27442                                    Isotectorigenin   TRUE   solid
# 27470                                 Petroselaidic acid   TRUE   solid
#
#       annotation_quality                                        description  \
# 0                    low      Constit. of Morus alba (white mulberry) [CCD]
# 1                    low      Constit. of the leaves of Nymphaea alba [CCD]
# 2                    low             Constit. of Phragmites australis [CCD]
# 13                   low           Isol. from red wine incl. Pinotage (CCD)
# 15                   low  A polyphenol compound found in foods of plant ...
# 25                   low  Luteolinidin is a chemical compound belonging ...
# 32                   low
# 33                   low  A polyphenol compound found in foods of plant ...
# 67                   low  Constit. of Allium cepa (red onion). Also obt....
# 68                   low  Isol. from various plants incl. many Asteracea...
# 70                   low  Constit. of Brassica oleracea var. costata (tr...
# 73                   low  Constit. of Brassica oleracea var. costata (tr...
# 78                   low  Constit. of Ranunculus subgenus Batrachium sp....
# 96                   low  Digallic acid is a polyphenolic compound found...
# 121                  low
# 122                  low
# 126                  low
# 127                  low  A polyphenol compound found in foods of plant ...
# 151                  low              Constit. of roasted cocoa beans [CCD]
# 152                  low  Constit. of Arabidopsis thaliana. Also found i...
# 153                  low  Constit. of cocoa flowers and robusta coffee b...
# 154                  low  Constit. of the bark of Dalbergia melanoxylon ...
# 173                  low
# 197                  low
# 199                  low
# 200                  low  Growth promoter for livestock. Permitted in th...
# 201                  low     From Phaseolus coccineus (scarlet runner bean)
# 202                  low                     Isol. from peel of Citrus spp.
# 203                  low           Constit. of Allium vineale (wild garlic)
# 204                  low
# ...                  ...                                                ...
# 19432                low  The phosphoric acid ester of serine. As a cons...
# 19612                low  4-phenylbutyrate (4-PBA) is known to be a tran...
# 19650                low  D-Ribulose 5-phosphate is a metabolite in the ...
# 19654                low  D-Leucic acid is an alpha-hydroxycarboxylic ac...
# 19676                low  Leucinic acid has been isolated from amniotic ...
# 19723                low  Hydroxyisocaproic acid is derived from the met...
# 19734                low  A bile acid. Bile acids are steroid acids foun...
# 19741                low  Phenyllactic acid a product of phenylalanine c...
# 19907                low  Simple amine found in the brain. It may be mod...
# 19965                low  Lathosterol is a a sterol (a combination stero...
# 20169                low  Present in mucopolysaccharides and in polysacc...
# 20201                low  It is a normal metabolite found in human biofl...
# 20295                low  A compound composed of the standard 2,3-dimeth...
# 20319                low  A cyclic dipeptide initially described in both...
# 20436                low  7,7',8,8',11,12-Hexahydro-Carotene  is a carot...
# 20569                low  Testerone is a predominantly male hormone, tho...
# 20628                low  Dihydrocortisol is the product of the enzyme S...
# 20655                low  2-Phosphoglyceric acid (2PGA) is a glyceric ac...
# 20778                low  11beta-Hydroxyprogesterone is a normal human m...
# 21073                low  Lansoprazole is a proton pump inhibitor simila...
# 21286                low  Metab. produced during NADPH dependent enzymat...
# 21327                low  A clear, colorless, viscous organic solvent an...
# 25353                low  ==(R)==-3-Hydroxyhexanoic acid is a fatty acid...
# 25814                low  Occurs with D-glucitol in the berry of mountai...
# 25901                low  N-Acetylmannosamine is a monosaccharide involv...
# 27141                low                    Flavouring compound [Flavornet]
# 27264                low  Inhibits bone resorption via PGE2 synthesis in...
# 27394                low  Constit. of the heartwood of Dalbergia melanox...
# 27442                low  Isol. from Dalbergia sissoo bark, Millettia au...
# 27470                low  Minor constit. of plant oils. Constit. of milk...
#
#         cas_number     ...                                     superklass  \
# 0      101365-02-0     ...               Phenylpropanoids and polyketides
# 1      350602-26-5     ...               Phenylpropanoids and polyketides
# 2      216692-08-9     ...               Phenylpropanoids and polyketides
# 13     663910-41-6     ...               Phenylpropanoids and polyketides
# 15                     ...               Phenylpropanoids and polyketides
# 25       1154-78-5     ...               Phenylpropanoids and polyketides
# 32                     ...
# 33                     ...               Phenylpropanoids and polyketides
# 67     133563-23-2     ...               Phenylpropanoids and polyketides
# 68          2/2/68     ...               Phenylpropanoids and polyketides
# 70        520-18-3     ...               Phenylpropanoids and polyketides
# 73        520-18-3     ...
# 78     194093-39-5     ...               Phenylpropanoids and polyketides
# 96        536-08-3     ...
# 121                    ...
# 122                    ...
# 126                    ...
# 127                    ...      Lignans, neolignans and related compounds
# 151    860295-20-1     ...                  Organic acids and derivatives
# 152    151435-24-4     ...                  Organic acids and derivatives
# 153    124027-56-1     ...                  Organic acids and derivatives
# 154     77201-64-0     ...                  Organic acids and derivatives
# 173                    ...
# 197       586-37-8     ...
# 199      6811-35-4     ...
# 200        50-28-2     ...                Lipids and lipid-like molecules
# 201                    ...               Phenylpropanoids and polyketides
# 202      1251-84-9     ...               Phenylpropanoids and polyketides
# 203    113576-37-7     ...                Lipids and lipid-like molecules
# 204     19057-60-4     ...
# ...            ...     ...                                            ...
# 19432     407-41-0     ...                  Organic acids and derivatives
# 19612    1821-12-1     ...                                     Benzenoids
# 19650    4151-19-3     ...
# 19654   20312-37-2     ...
# 19676     498-36-2     ...                Lipids and lipid-like molecules
# 19723   13748-90-8     ...
# 19734     547-75-1     ...
# 19741     828-01-3     ...               Phenylpropanoids and polyketides
# 19907    7568-93-6     ...
# 19965      80-99-9     ...                Lipids and lipid-like molecules
# 20169    3416-24-8     ...                         Organooxygen compounds
# 20201   17885-08-4     ...                  Organic acids and derivatives
# 20295     727-81-1     ...                Lipids and lipid-like molecules
# 20319   53109-32-3     ...
# 20436     540-05-6     ...                Lipids and lipid-like molecules
# 20569     651-45-6     ...                Lipids and lipid-like molecules
# 20628    1482-50-4     ...
# 20655    2553-59-5     ...
# 20778     600-57-7     ...
# 21073  103577-45-3     ...                   Organoheterocyclic compounds
# 21286   79551-86-3     ...                Lipids and lipid-like molecules
# 21327    4254-15-3     ...                         Organooxygen compounds
# 25353   77877-35-1     ...
# 25814     488-45-9     ...                         Organooxygen compounds
# 25901    3615-17-6     ...                         Organooxygen compounds
# 27141     502-99-8     ...
# 27264     863-61-6     ...
# 27394   58115-08-5     ...               Phenylpropanoids and polyketides
# 27442   13111-57-4     ...
# 27470     593-40-8     ...
#
#                                            klass  \
# 0                    2-arylbenzofuran flavonoids
# 1                                     Flavonoids
# 2                                     Flavonoids
# 13                                    Flavonoids
# 15                                    Flavonoids
# 25                                    Flavonoids
# 32
# 33                   Linear 1,3-diarylpropanoids
# 67                                    Flavonoids
# 68                                    Flavonoids
# 70                                    Flavonoids
# 73
# 78                                    Flavonoids
# 96
# 121
# 122
# 126
# 127
# 151             Carboxylic acids and derivatives
# 152             Carboxylic acids and derivatives
# 153             Carboxylic acids and derivatives
# 154             Carboxylic acids and derivatives
# 173
# 197
# 199
# 200             Steroids and steroid derivatives
# 201                                Isoflavonoids
# 202                                   Flavonoids
# 203             Steroids and steroid derivatives
# 204
# ...                                          ...
# 19432           Carboxylic acids and derivatives
# 19612        Benzene and substituted derivatives
# 19650
# 19654
# 19676                                Fatty Acyls
# 19723
# 19734
# 19741                      Phenylpropanoic acids
# 19907
# 19965           Steroids and steroid derivatives
# 20169  Carbohydrates and carbohydrate conjugates
# 20201           Carboxylic acids and derivatives
# 20295                              Prenol lipids
# 20319
# 20436                              Prenol lipids
# 20569           Steroids and steroid derivatives
# 20628
# 20655
# 20778
# 21073                             Benzimidazoles
# 21286                                Fatty Acyls
# 21327                       Alcohols and polyols
# 25353
# 25814  Carbohydrates and carbohydrate conjugates
# 25901  Carbohydrates and carbohydrate conjugates
# 27141
# 27264
# 27394                              Neoflavonoids
# 27442
# 27470
#
#                                    subklass  \
# 0
# 1                      Flavonoid glycosides
# 2                      Flavonoid glycosides
# 13                     Flavonoid glycosides
# 15                     Flavonoid glycosides
# 25                        Hydroxyflavonoids
# 32
# 33           Chalcones and dihydrochalcones
# 67                     Flavonoid glycosides
# 68                  O-methylated flavonoids
# 70                     Flavonoid glycosides
# 73
# 78                     Flavonoid glycosides
# 96
# 121
# 122
# 126
# 127
# 151    Amino acids, peptides, and analogues
# 152    Amino acids, peptides, and analogues
# 153    Amino acids, peptides, and analogues
# 154    Amino acids, peptides, and analogues
# 173
# 197
# 199
# 200                        Estrane steroids
# 201                          Isoflav-2-enes
# 202                 O-methylated flavonoids
# 203                    Steroidal glycosides
# 204
# ...                                     ...
# 19432  Amino acids, peptides, and analogues
# 19612
# 19650
# 19654
# 19676            Fatty acids and conjugates
# 19723
# 19734
# 19741
# 19907
# 19965                   Cholestane steroids
# 20169                      Aminosaccharides
# 20201  Amino acids, peptides, and analogues
# 20295       Quinone and hydroquinone lipids
# 20319
# 20436                       Tetraterpenoids
# 20569                     Sulfated steroids
# 20628
# 20655
# 20778
# 21073                Sulfinylbenzimidazoles
# 21286            Fatty acids and conjugates
# 21327                               Polyols
# 25353
# 25814                        Sugar alcohols
# 25901                      Aminosaccharides
# 27141
# 27264
# 27394                           Neoflavones
# 27442
# 27470
#
#                                    direct_parent  \
# 0                    2-arylbenzofuran flavonoids
# 1                   Anthocyanidin-3-O-glycosides
# 2                   Anthocyanidin-3-O-glycosides
# 13                      Flavonoid-3-O-glycosides
# 15                  Anthocyanidin-3-O-glycosides
# 25                           7-hydroxyflavonoids
# 32
# 33                Chalcones and dihydrochalcones
# 67                      Flavonoid-7-O-glycosides
# 68                     7-O-methylated flavonoids
# 70                      Flavonoid-7-O-glycosides
# 73
# 78                      Flavonoid-7-O-glycosides
# 96
# 121
# 122
# 126
# 127    Lignans, neolignans and related compounds
# 151           N-acyl-aliphatic-alpha amino acids
# 152           N-acyl-aliphatic-alpha amino acids
# 153           N-acyl-aliphatic-alpha amino acids
# 154           N-acyl-aliphatic-alpha amino acids
# 173
# 197
# 199
# 200                    Estrogens and derivatives
# 201                                  Isoflavones
# 202                    7-O-methylated flavonoids
# 203                           Steroidal saponins
# 204
# ...                                          ...
# 19432                        L-alpha-amino acids
# 19612        Benzene and substituted derivatives
# 19650
# 19654
# 19676                        Hydroxy fatty acids
# 19723
# 19734
# 19741                      Phenylpropanoic acids
# 19907
# 19965               Cholesterols and derivatives
# 20169                               Amino sugars
# 20201                          Alpha amino acids
# 20295                                Ubiquinones
# 20319
# 20436                                  Carotenes
# 20569                          Sulfated steroids
# 20628
# 20655
# 20778
# 21073                     Sulfinylbenzimidazoles
# 21286                     Long-chain fatty acids
# 21327                                  1,2-diols
# 25353
# 25814                             Sugar alcohols
# 25901                            Acylaminosugars
# 27141
# 27264
# 27394                                Neoflavones
# 27442
# 27470
#
#                         molecular_framework      chembl_id chemspider_id  \
# 0       Aromatic heteropolycyclic compounds
# 1       Aromatic heteropolycyclic compounds
# 2       Aromatic heteropolycyclic compounds
# 13      Aromatic heteropolycyclic compounds                     10286568
# 15      Aromatic heteropolycyclic compounds
# 25      Aromatic heteropolycyclic compounds  CHEMBL1275834        390308
# 32
# 33        Aromatic homomonocyclic compounds   CHEMBL492818       9953627
# 67      Aromatic heteropolycyclic compounds
# 68      Aromatic heteropolycyclic compounds   CHEMBL164861       4444090
# 70      Aromatic heteropolycyclic compounds
# 73
# 78      Aromatic heteropolycyclic compounds
# 96
# 121
# 122
# 126
# 127       Aromatic homomonocyclic compounds                     29336462
# 151       Aromatic homomonocyclic compounds
# 152       Aromatic homomonocyclic compounds                     32175166
# 153       Aromatic homomonocyclic compounds                     22546930
# 154       Aromatic homomonocyclic compounds
# 173
# 197
# 199
# 200       Aromatic homopolycyclic compounds      CHEMBL135          5554
# 201     Aromatic heteropolycyclic compounds                     30776770
# 202     Aromatic heteropolycyclic compounds   CHEMBL225698        342371
# 203    Aliphatic heteropolycyclic compounds
# 204
# ...                                     ...            ...           ...
# 19432           Aliphatic acyclic compounds   CHEMBL284377         62074
# 19612     Aromatic homomonocyclic compounds     CHEMBL1469          4611
# 19650
# 19654                                                             388986
# 19676           Aliphatic acyclic compounds  CHEMBL3247392         83753
# 19723                                                              75520
# 19734
# 19741     Aromatic homomonocyclic compounds  CHEMBL1778420          3715
# 19907                                          CHEMBL19216           975
# 19965    Aliphatic homopolycyclic compounds  CHEMBL3138639         59151
# 20169  Aliphatic heteromonocyclic compounds   CHEMBL493287        388352
# 20201           Aliphatic acyclic compounds                          104
# 20295    Aliphatic homomonocyclic compounds  CHEMBL1236594          4307
# 20319                                                              58646
# 20436           Aliphatic acyclic compounds                      4941340
# 20569    Aliphatic homopolycyclic compounds                       106493
# 20628                                                             144508
# 20655                                                                 58
# 20778                                                           24840621
# 21073   Aromatic heteropolycyclic compounds      CHEMBL480          3746
# 21286           Aliphatic acyclic compounds                      4446281
# 21327           Aliphatic acyclic compounds                       388890
# 25353                                                            8373213
# 25814           Aliphatic acyclic compounds                      4573729
# 25901  Aliphatic heteromonocyclic compounds                      9271300
# 27141
# 27264
# 27394   Aromatic heteropolycyclic compounds  CHEMBL2397755        391130
# 27442
# 27470
#
#                               meta_cyc_id foodcomex phytohub_id
# 0
# 1
# 2
# 13
# 15
# 25                              CPD-11945
# 32
# 33
# 67
# 68     345-TRIHYDROXY-37-DIMETHOXYFLAVONE
# 70
# 73
# 78
# 96
# 121
# 122
# 126
# 127
# 151
# 152
# 153
# 154
# 173
# 197
# 199
# 200                               CPD-352      TRUE
# 201
# 202
# 203
# 204
# ...                                   ...       ...         ...
# 19432                          3-P-SERINE      TRUE
# 19612                                          TRUE
# 19650                         RIBULOSE-5P
# 19654
# 19676                                          TRUE
# 19723                                          TRUE
# 19734
# 19741                            CPD-6978      TRUE
# 19907                  PHENYLETHANOLAMINE      TRUE
# 19965                            CPD-4186      TRUE
# 20169                         GLUCOSAMINE      TRUE
# 20201                          3-P-SERINE      TRUE
# 20295                           CPD0-1118
# 20319
# 20436                             CPD-449
# 20569              19-HYDROXYTESTOSTERONE
# 20628
# 20655                                2-PG
# 20778                             CPD-272
# 21073                                          TRUE
# 21286
# 21327                              #NAME?
# 25353
# 25814                             CPD-369      TRUE
# 25901              N-ACETYL-D-MANNOSAMINE      TRUE
# 27141
# 27264
# 27394
# 27442
# 27470
#
# [15059 rows x 106 columns]

# %%
#Are any of the legacy_ids shared between compounds and nutrients?
#No.
compounds_legacy_ids = list(compounds['legacy_id'])
nutrients_legacy_ids = list(nutrients['legacy_id'])
shared_compnutr_legacy_ids = []
#for sub in subgroups:
#    if any(generic in sub for generic in generics):
#        generic_subgroups.append(sub)
for comp in compounds_legacy_ids:
    for nutr in nutrients_legacy_ids:
        if comp == nutr:
            shared_compnutr_legacy_ids.append(comp)

# %%
#38 shared compound/nutrient legacy ids, which means 38 compounds are nutrientsbbb
len(shared_compnutr_legacy_ids)
# Out:
# 0

# %%
foodcomex_compounds = pd.read_sql_query('''SELECT fcc.* 
                            FROM foodcomex_compounds fcc
                            ;''', engine)
# Out:
# 2019-03-17 10:09:31,085 INFO sqlalchemy.engine.base.Engine SELECT fcc.*
#                             FROM foodcomex_compounds fcc
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT fcc.*
#                             FROM foodcomex_compounds fcc
#                             ;
# 2019-03-17 10:09:31,085 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
foodcomex_compounds.head()
# Out:
#   id compound_id      origin storage_form maximum_quantity  \
# 0  1        9021  commercial        solid                5
# 1  2       12167  commercial        solid                6
# 2  3       22309  commercial        solid                1
# 3  4       22088  commercial        solid                8
# 4  5       12686  commercial        solid                1
#
#      storage_condition       contact_name  \
# 0  temperature: -80 oC  Dr. David Wishart
# 1  temperature: -80 oC  Dr. David Wishart
# 2  temperature: -80 oC  Dr. David Wishart
# 3  temperature: -80 oC  Dr. David Wishart
# 4  temperature: -80 oC  Dr. David Wishart
#
#                                      contact_address         contact_email  \
# 0  Departments of Computing Science and Biologica...  dwishart@ualberta.ca
# 1  Departments of Computing Science and Biologica...  dwishart@ualberta.ca
# 2  Departments of Computing Science and Biologica...  dwishart@ualberta.ca
# 3  Departments of Computing Science and Biologica...  dwishart@ualberta.ca
# 4  Departments of Computing Science and Biologica...  dwishart@ualberta.ca
#
#             created_at        ...         production_method_reference_text  \
# 0  2015-10-09 22:27:11        ...
# 1  2015-10-09 22:27:12        ...
# 2  2015-10-09 22:27:13        ...
# 3  2015-10-09 22:27:13        ...
# 4  2015-10-09 22:27:13        ...
#
#   production_method_reference_file_name  \
# 0                                  NULL
# 1                                  NULL
# 2                                  NULL
# 3                                  NULL
# 4                                  NULL
#
#   production_method_reference_content_type  \
# 0                                     NULL
# 1                                     NULL
# 2                                     NULL
# 3                                     NULL
# 4                                     NULL
#
#   production_method_reference_file_size  \
# 0                                  NULL
# 1                                  NULL
# 2                                  NULL
# 3                                  NULL
# 4                                  NULL
#
#   production_method_reference_updated_at elemental_formula minimum_quantity  \
# 0                                   NULL
# 1                                   NULL
# 2                                   NULL
# 3                                   NULL
# 4                                   NULL
#
#   quantity_units available_spectra storage_conditions
# 0              g              NULL   ---\n\-80Â°C\: 1
# 1              g              NULL   ---\n\-80Â°C\: 1
# 2              g              NULL   ---\n\-80Â°C\: 1
# 3              g              NULL   ---\n\-80Â°C\: 1
# 4              g              NULL   ---\n\-80Â°C\: 1
#
# [5 rows x 36 columns]

# %%
foodcomex_compounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 36 columns):
# id                                          1044 non-null object
# compound_id                                 1044 non-null object
# origin                                      1044 non-null object
# storage_form                                1044 non-null object
# maximum_quantity                            1044 non-null object
# storage_condition                           1044 non-null object
# contact_name                                1044 non-null object
# contact_address                             1044 non-null object
# contact_email                               1044 non-null object
# created_at                                  1044 non-null object
# updated_at                                  1044 non-null object
# export                                      1044 non-null object
# purity                                      1044 non-null object
# description                                 1044 non-null object
# spectra_details                             1044 non-null object
# delivery_time                               1044 non-null object
# stability                                   1044 non-null object
# admin_user_id                               1044 non-null object
# public_id                                   1044 non-null object
# cas_number                                  1044 non-null object
# taxonomy_class                              1044 non-null object
# taxonomy_family                             1044 non-null object
# experimental_logp                           1044 non-null object
# experimental_solubility                     1044 non-null object
# melting_point                               1044 non-null object
# food_of_origin                              1044 non-null object
# production_method_reference_text            1044 non-null object
# production_method_reference_file_name       1044 non-null object
# production_method_reference_content_type    1044 non-null object
# production_method_reference_file_size       1044 non-null object
# production_method_reference_updated_at      1044 non-null object
# elemental_formula                           1044 non-null object
# minimum_quantity                            1044 non-null object
# quantity_units                              1044 non-null object
# available_spectra                           1044 non-null object
# storage_conditions                          1044 non-null object
# dtypes: object(36)
# memory usage: 293.7+ KB

# %%
get_value_from_cols(foodcomex_compounds, 'NULL')
# Out:
# id 0
# compound_id 0
# origin 0
# storage_form 0
# maximum_quantity 33
# storage_condition 22
# contact_name 23
# contact_address 23
# contact_email 23
# created_at 0
# updated_at 0
# export 0
# purity 1005
# description 1005
# spectra_details 1028
# delivery_time 1005
# stability 1005
# admin_user_id 0
# public_id 0
# cas_number 0
# taxonomy_class 0
# taxonomy_family 0
# experimental_logp 0
# experimental_solubility 0
# melting_point 0
# food_of_origin 0
# production_method_reference_text 0
# production_method_reference_file_name 1043
# production_method_reference_content_type 1043
# production_method_reference_file_size 1043
# production_method_reference_updated_at 1043
# elemental_formula 0
# minimum_quantity 0
# quantity_units 0
# available_spectra 1005
# storage_conditions 0

# %%
#Do food comex compound compound_ids match the compounds.ids?
#Yes. This accounts for 1044 compounds.
compounds_from_foodcomex = pd.read_sql_query('''SELECT c.*
                FROM compounds c
                JOIN foodcomex_compounds fcc ON fcc.compound_id == c.id
                WHERE c.id == fcc.compound_id
                ;''', engine)
# Out:
# 2019-03-17 10:15:17,791 INFO sqlalchemy.engine.base.Engine SELECT c.*
#                 FROM compounds c
#                 JOIN foodcomex_compounds fcc ON fcc.compound_id == c.id
#                 WHERE c.id == fcc.compound_id
#                 ;
# INFO:sqlalchemy.engine.base.Engine:SELECT c.*
#                 FROM compounds c
#                 JOIN foodcomex_compounds fcc ON fcc.compound_id == c.id
#                 WHERE c.id == fcc.compound_id
#                 ;
# 2019-03-17 10:15:17,793 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds_from_foodcomex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Columns: 106 entries, id to phytohub_id
# dtypes: object(106)
# memory usage: 864.6+ KB

# %%
pathways = pd.read_sql_query('''SELECT p.* 
                            FROM pathways p
                            ;''', engine)
# Out:
# 2019-03-17 09:43:39,275 INFO sqlalchemy.engine.base.Engine SELECT p.*
#                             FROM pathways p
#                             ;
# 2019-03-17 09:43:39,276 INFO sqlalchemy.engine.base.Engine ()

# %%
#Possible link between kegg_mag_id and compounds.kegg_compound_id, but only for about 3000 compounds
pathways.head()
# Out:
#   id  smpdb_id kegg_map_id                              name  \
# 0  1  SMP00006    map00350               Tyrosine Metabolism
# 1  2  SMP00068    map00150  Androgen and Estrogen Metabolism
# 2  3  SMP00011    map00562               Inositol Metabolism
# 3  4  SMP00462    map00562     Inositol Phosphate Metabolism
# 4  5  SMP00012    map00350        Catecholamine Biosynthesis
#
#             created_at           updated_at
# 0  2015-02-23 22:40:48  2015-02-23 22:40:48
# 1  2015-02-23 22:40:58  2015-02-23 22:40:58
# 2  2015-02-23 22:41:14  2015-02-23 22:41:14
# 3  2015-02-23 22:41:14  2015-02-23 22:41:14
# 4  2015-02-23 22:42:38  2015-02-23 22:42:38

# %%
nutrients = pd.read_sql_query('''SELECT n.* 
                            FROM nutrients n
                            ;''', engine)
# Out:
# 2019-03-17 09:46:42,081 INFO sqlalchemy.engine.base.Engine SELECT n.*
#                             FROM nutrients n
#                             ;
# 2019-03-17 09:46:42,091 INFO sqlalchemy.engine.base.Engine ()

# %%
nutrients
# Out:
#     id legacy_id      type  public_id                        name export  \
# 0    1     10930  Nutrient  FDBN00001                         Fat      0
# 1    2     10946  Nutrient  FDBN00002                    Proteins      0
# 2    3     16037  Nutrient  FDBN00003                Carbohydrate      0
# 3    4     23404  Nutrient  FDBN00004                 Fatty acids      0
# 4    5     11134  Nutrient  FDBN00005             Fiber (dietary)      0
# 5    6     58893  Nutrient  FDBN00006                        13:0      0
# 6    7     58894  Nutrient  FDBN00007                        14:1      0
# 7    8     58895  Nutrient  FDBN00008                        15:1      0
# 8    9     58896  Nutrient  FDBN00009                      16:1 c      0
# 9   10     58897  Nutrient  FDBN00010                      16:1 t      0
# 10  11     58898  Nutrient  FDBN00011       16:1 undifferentiated      0
# 11  12     58899  Nutrient  FDBN00012                        17:1      0
# 12  13     58900  Nutrient  FDBN00013                      18:1 c      0
# 13  14     58901  Nutrient  FDBN00014                      18:1 t      0
# 14  15     58902  Nutrient  FDBN00015       18:1 undifferentiated      0
# 15  16     58903  Nutrient  FDBN00016                   18:2 CLAs      0
# 16  17     58904  Nutrient  FDBN00017                      18:2 i      0
# 17  18     58905  Nutrient  FDBN00018  18:2 t not further defined      0
# 18  19     58906  Nutrient  FDBN00019                    18:2 t,t      0
# 19  20     58907  Nutrient  FDBN00020       18:2 undifferentiated      0
# 20  21     58908  Nutrient  FDBN00021       18:3 undifferentiated      0
# 21  22     58909  Nutrient  FDBN00022                       18:3i      0
# 22  23     58910  Nutrient  FDBN00023                        18:4      0
# 23  24     58911  Nutrient  FDBN00024                        20:1      0
# 24  25     58912  Nutrient  FDBN00025                20:2 n-6 c,c      0
# 25  26     58913  Nutrient  FDBN00026                    20:3 n-3      0
# 26  27     58914  Nutrient  FDBN00027                    20:3 n-6      0
# 27  28     58915  Nutrient  FDBN00028       20:3 undifferentiated      0
# 28  29     58916  Nutrient  FDBN00029       20:4 undifferentiated      0
# 29  30     58917  Nutrient  FDBN00030                        21:5      0
# 30  31     58918  Nutrient  FDBN00031                        22:0      0
# 31  32     58919  Nutrient  FDBN00032                      22:1 c      0
# 32  33     58920  Nutrient  FDBN00033                      22:1 t      0
# 33  34     58921  Nutrient  FDBN00034       22:1 undifferentiated      0
# 34  35     58922  Nutrient  FDBN00035                        22:4      0
# 35  36     58923  Nutrient  FDBN00036                    22:5 n-3      0
# 36  37     58924  Nutrient  FDBN00037                      24:1 c      0
# 37  38     58928  Nutrient  FDBN00038                      Energy      0
#
#    state annotation_quality  \
# 0   NULL                low
# 1   NULL                low
# 2   NULL                low
# 3   NULL                low
# 4   NULL                low
# 5   NULL                low
# 6   NULL                low
# 7   NULL                low
# 8   NULL                low
# 9   NULL                low
# 10  NULL                low
# 11  NULL                low
# 12  NULL                low
# 13  NULL                low
# 14  NULL                low
# 15  NULL                low
# 16  NULL                low
# 17  NULL                low
# 18  NULL                low
# 19  NULL                low
# 20  NULL                low
# 21  NULL                low
# 22  NULL                low
# 23  NULL                low
# 24  NULL                low
# 25  NULL                low
# 26  NULL                low
# 27  NULL                low
# 28  NULL                low
# 29  NULL                low
# 30  NULL                low
# 31  NULL                low
# 32  NULL                low
# 33  NULL                low
# 34  NULL                low
# 35  NULL                low
# 36  NULL                low
# 37  NULL                low
#
#                                           description  wikipedia_id  \
# 0                                                NULL          NULL
# 1                                                NULL          NULL
# 2   Carbohydrates (or saccharides) are organic com...  Carbohydrate
# 3                                                NULL          NULL
# 4                                                NULL          NULL
# 5                                                NULL          NULL
# 6                                                NULL          NULL
# 7                                                NULL          NULL
# 8                                                NULL          NULL
# 9                                                NULL          NULL
# 10                                               NULL          NULL
# 11                                               NULL          NULL
# 12                                               NULL          NULL
# 13                                               NULL          NULL
# 14                                               NULL          NULL
# 15                                               NULL          NULL
# 16                                               NULL          NULL
# 17                                               NULL          NULL
# 18                                               NULL          NULL
# 19                                               NULL          NULL
# 20                                               NULL          NULL
# 21                                               NULL          NULL
# 22                                               NULL          NULL
# 23                                               NULL          NULL
# 24                                               NULL          NULL
# 25                                               NULL          NULL
# 26                                               NULL          NULL
# 27                                               NULL          NULL
# 28                                               NULL          NULL
# 29                                               NULL          NULL
# 30                                               NULL          NULL
# 31                                               NULL          NULL
# 32                                               NULL          NULL
# 33                                               NULL          NULL
# 34                                               NULL          NULL
# 35                                               NULL          NULL
# 36                                               NULL          NULL
# 37                                               NULL          NULL
#
#            ...          eafus_id dfc_name compound_source metabolism  \
# 0          ...              NULL     NULL            DUKE       NULL
# 1          ...              NULL     NULL            DUKE       NULL
# 2          ...              NULL     NULL            DUKE       NULL
# 3          ...              1335     NULL           EAFUS       NULL
# 4          ...              NULL     NULL            DUKE       NULL
# 5          ...              NULL     NULL          TABLES       NULL
# 6          ...              NULL     NULL          TABLES       NULL
# 7          ...              NULL     NULL          TABLES       NULL
# 8          ...              NULL     NULL          TABLES       NULL
# 9          ...              NULL     NULL          TABLES       NULL
# 10         ...              NULL     NULL          TABLES       NULL
# 11         ...              NULL     NULL          TABLES       NULL
# 12         ...              NULL     NULL          TABLES       NULL
# 13         ...              NULL     NULL          TABLES       NULL
# 14         ...              NULL     NULL          TABLES       NULL
# 15         ...              NULL     NULL          TABLES       NULL
# 16         ...              NULL     NULL          TABLES       NULL
# 17         ...              NULL     NULL          TABLES       NULL
# 18         ...              NULL     NULL          TABLES       NULL
# 19         ...              NULL     NULL          TABLES       NULL
# 20         ...              NULL     NULL          TABLES       NULL
# 21         ...              NULL     NULL          TABLES       NULL
# 22         ...              NULL     NULL          TABLES       NULL
# 23         ...              NULL     NULL          TABLES       NULL
# 24         ...              NULL     NULL          TABLES       NULL
# 25         ...              NULL     NULL          TABLES       NULL
# 26         ...              NULL     NULL          TABLES       NULL
# 27         ...              NULL     NULL          TABLES       NULL
# 28         ...              NULL     NULL          TABLES       NULL
# 29         ...              NULL     NULL          TABLES       NULL
# 30         ...              NULL     NULL          TABLES       NULL
# 31         ...              NULL     NULL          TABLES       NULL
# 32         ...              NULL     NULL          TABLES       NULL
# 33         ...              NULL     NULL          TABLES       NULL
# 34         ...              NULL     NULL          TABLES       NULL
# 35         ...              NULL     NULL          TABLES       NULL
# 36         ...              NULL     NULL          TABLES       NULL
# 37         ...              NULL     NULL          TABLES       NULL
#
#    synthesis_citations general_citations creator_id updater_id  \
# 0                 NULL              NULL       NULL       NULL
# 1                 NULL              NULL       NULL       NULL
# 2                 NULL              NULL       NULL       NULL
# 3                 NULL              NULL       NULL       NULL
# 4                 NULL              NULL       NULL       NULL
# 5                 NULL              NULL       NULL       NULL
# 6                 NULL              NULL       NULL       NULL
# 7                 NULL              NULL       NULL       NULL
# 8                 NULL              NULL       NULL       NULL
# 9                 NULL              NULL       NULL       NULL
# 10                NULL              NULL       NULL       NULL
# 11                NULL              NULL       NULL       NULL
# 12                NULL              NULL       NULL       NULL
# 13                NULL              NULL       NULL       NULL
# 14                NULL              NULL       NULL       NULL
# 15                NULL              NULL       NULL       NULL
# 16                NULL              NULL       NULL       NULL
# 17                NULL              NULL       NULL       NULL
# 18                NULL              NULL       NULL       NULL
# 19                NULL              NULL       NULL       NULL
# 20                NULL              NULL       NULL       NULL
# 21                NULL              NULL       NULL       NULL
# 22                NULL              NULL       NULL       NULL
# 23                NULL              NULL       NULL       NULL
# 24                NULL              NULL       NULL       NULL
# 25                NULL              NULL       NULL       NULL
# 26                NULL              NULL       NULL       NULL
# 27                NULL              NULL       NULL       NULL
# 28                NULL              NULL       NULL       NULL
# 29                NULL              NULL       NULL       NULL
# 30                NULL              NULL       NULL       NULL
# 31                NULL              NULL       NULL       NULL
# 32                NULL              NULL       NULL       NULL
# 33                NULL              NULL       NULL       NULL
# 34                NULL              NULL       NULL       NULL
# 35                NULL              NULL       NULL       NULL
# 36                NULL              NULL       NULL       NULL
# 37                NULL              NULL       NULL       NULL
#
#              created_at           updated_at
# 0   2014-11-05 13:42:10  2014-11-05 13:42:10
# 1   2014-11-05 13:42:15  2014-11-05 13:42:15
# 2   2014-11-05 13:44:06  2014-11-05 13:44:06
# 3   2014-11-05 13:46:00  2014-11-05 13:46:00
# 4   2014-11-05 13:47:36  2014-11-05 13:47:36
# 5   2014-11-05 13:49:16  2014-11-05 13:49:16
# 6   2014-11-05 13:49:19  2014-11-05 13:49:19
# 7   2014-11-05 13:49:38  2014-11-05 13:49:38
# 8   2014-11-05 13:49:52  2014-11-05 13:49:52
# 9   2014-11-05 13:49:59  2014-11-05 13:49:59
# 10  2014-11-05 13:50:04  2014-11-05 13:50:04
# 11  2014-11-05 13:51:16  2014-11-05 13:51:16
# 12  2014-11-05 13:51:34  2014-11-05 13:51:34
# 13  2014-11-05 13:51:45  2014-11-05 13:51:45
# 14  2014-11-05 13:51:57  2014-11-05 13:51:57
# 15  2014-11-05 13:53:09  2014-11-05 13:53:09
# 16  2014-11-05 13:53:16  2014-11-05 13:53:16
# 17  2014-11-05 13:53:17  2014-11-05 13:53:17
# 18  2014-11-05 13:53:23  2014-11-05 13:53:23
# 19  2014-11-05 13:53:26  2014-11-05 13:53:26
# 20  2014-11-05 13:54:38  2014-11-05 13:54:38
# 21  2014-11-05 13:55:48  2014-11-05 13:55:48
# 22  2014-11-05 13:55:49  2014-11-05 13:55:49
# 23  2014-11-05 13:56:45  2014-11-05 13:56:45
# 24  2014-11-05 13:57:50  2014-11-05 13:57:50
# 25  2014-11-05 13:58:07  2014-11-05 13:58:07
# 26  2014-11-05 13:58:11  2014-11-05 13:58:11
# 27  2014-11-05 13:58:16  2014-11-05 13:58:16
# 28  2014-11-05 13:58:33  2014-11-05 13:58:33
# 29  2014-11-05 13:59:36  2014-11-05 13:59:36
# 30  2014-11-05 13:59:37  2014-11-05 13:59:37
# 31  2014-11-05 14:00:03  2014-11-05 14:00:03
# 32  2014-11-05 14:00:09  2014-11-05 14:00:09
# 33  2014-11-05 14:00:14  2014-11-05 14:00:14
# 34  2014-11-05 14:01:10  2014-11-05 14:01:10
# 35  2014-11-05 14:01:15  2014-11-05 14:01:15
# 36  2014-11-05 14:02:21  2014-11-05 14:02:21
# 37  2014-11-05 14:02:28  2014-11-05 14:02:28
#
# [38 rows x 23 columns]

# %%
nutrients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 23 columns):
# id                     38 non-null object
# legacy_id              38 non-null object
# type                   38 non-null object
# public_id              38 non-null object
# name                   38 non-null object
# export                 38 non-null object
# state                  38 non-null object
# annotation_quality     38 non-null object
# description            38 non-null object
# wikipedia_id           38 non-null object
# comments               38 non-null object
# dfc_id                 38 non-null object
# duke_id                38 non-null object
# eafus_id               38 non-null object
# dfc_name               38 non-null object
# compound_source        38 non-null object
# metabolism             38 non-null object
# synthesis_citations    38 non-null object
# general_citations      38 non-null object
# creator_id             38 non-null object
# updater_id             38 non-null object
# created_at             38 non-null object
# updated_at             38 non-null object
# dtypes: object(23)
# memory usage: 6.9+ KB

# %%
get_value_from_cols(nutrients, 'NULL')
# Out:
# id 0
# legacy_id 0
# type 0
# public_id 0
# name 0
# export 0
# state 38
# annotation_quality 0
# description 37
# wikipedia_id 37
# comments 38
# dfc_id 38
# duke_id 33
# eafus_id 37
# dfc_name 38
# compound_source 0
# metabolism 38
# synthesis_citations 38
# general_citations 38
# creator_id 38
# updater_id 38
# created_at 0
# updated_at 0

# %%
references.head()
# Out:
#   id ref_type                                               text pubmed_id  \
# 0  1  general  Yannai, Shmuel. (2004) Dictionary of food comp...
# 1  2  general  Neveu V, Perez-Jimenez J, Vos F, Crespy V, du ...
# 2  3  general  Neveu V, Perez-Jimenez J, Vos F, Crespy V, du ...
# 3  4  general  de Villiers A, Vanhoenacker G, Majek P, Sandra...
# 4  5  general  Neveu V, Perez-Jimenez J, Vos F, Crespy V, du ...
#
#   link title creator_id updater_id           created_at           updated_at  \
# 0                  NULL       NULL  2015-02-23 22:39:47  2015-02-23 22:39:47
# 1                  NULL       NULL  2015-02-23 22:39:50  2015-02-23 22:39:50
# 2                  NULL       NULL  2015-02-23 22:39:50  2015-02-23 22:39:50
# 3                  NULL       NULL  2015-02-23 22:39:52  2015-02-23 22:39:52
# 4                  NULL       NULL  2015-02-23 22:39:54  2015-02-23 22:39:54
#
#   source_id source_type
# 0         1    Compound
# 1        22    Compound
# 2        48    Compound
# 3        52    Compound
# 4        59    Compound

# %%
references.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31791 entries, 0 to 31790
# Data columns (total 12 columns):
# id             31791 non-null object
# ref_type       31791 non-null object
# text           31791 non-null object
# pubmed_id      31791 non-null object
# link           31791 non-null object
# title          31791 non-null object
# creator_id     31791 non-null object
# updater_id     31791 non-null object
# created_at     31791 non-null object
# updated_at     31791 non-null object
# source_id      31791 non-null object
# source_type    31791 non-null object
# dtypes: object(12)
# memory usage: 2.9+ MB

# %%
#14674 source ids in references
#references['source_id'].value_counts()
#Drop pubmed_id, link, title, creator_id, updater_id

# %%
foods[foods['name_scientific'] == 'Callinectes sapidus']
# Out:
#       id       name      name_scientific  \
# 304  306  Blue crab  Callinectes sapidus
#
#                                            description itis_id  \
# 304  Callinectes sapidus (from the Greek calli- = "...   98696
#
#             wikipedia_id wikipedia_id_img picture_content_type  \
# 304  Callinectes_sapidus          306.jpg           image/jpeg
#
#     picture_file_size       picture_updated_at       ...       food_subgroup  \
# 304             69896  2012-04-20 09:32:04 UTC       ...         Crustaceans
#
#     food_type               created_at               updated_at creator_id  \
# 304    Type 1  2011-02-09 00:37:31 UTC  2017-03-20 21:26:27 UTC
#
#     updater_id export_to_afcdb  category ncbi_taxonomy_id export_to_foodb
# 304                      FALSE  specific             6763            TRUE
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Foods table

# %%
foods = pd.read_sql_query('''SELECT f.* 
                            FROM foods f
                            ;''', engine)
# Out:
# 2019-03-17 10:27:52,239 INFO sqlalchemy.engine.base.Engine SELECT f.*
#                             FROM foods f
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT f.*
#                             FROM foods f
#                             ;
# 2019-03-17 10:27:52,241 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
foods.head()
# Out:
#   id            name                 name_scientific  \
# 0  1        Angelica                Angelica keiskei
# 1  2   Savoy cabbage  Brassica oleracea var. sabauda
# 2  3   Silver linden                  Tilia argentea
# 3  4            Kiwi             Actinidia chinensis
# 4  5  Allium (Onion)                          Allium
#
#                                          description itis_id  \
# 0  Angelica is a genus of about 60 species of tal...
# 1  Savoy cabbage (Brassica oleracea convar. capit...
# 2  Tilia tomentosa (Silver Lime in the UK and Sil...
# 3  The kiwifruit, often shortened to kiwi in many...  506775
# 4  Allium haematochiton is a species of wild onio...   42634
#
#            wikipedia_id wikipedia_id_img picture_content_type  \
# 0              Angelica            1.jpg           image/jpeg
# 1         Savoy cabbage            2.jpg           image/jpeg
# 2       Tilia tomentosa            3.jpg           image/jpeg
# 3             Kiwifruit            4.jpg           image/jpeg
# 4  Allium haematochiton            5.jpg           image/jpeg
#
#   picture_file_size       picture_updated_at       ...        \
# 0            111325  2012-04-20 09:29:57 UTC       ...
# 1            155178  2012-04-20 09:39:54 UTC       ...
# 2             56367  2012-04-20 09:41:25 UTC       ...
# 3            110661  2012-04-20 09:32:21 UTC       ...
# 4            341911  2012-04-20 09:37:44 UTC       ...
#
#              food_subgroup food_type               created_at  \
# 0                    Herbs    Type 1  2011-02-09 00:37:14 UTC
# 1                 Cabbages    Type 1  2011-02-09 00:37:15 UTC
# 2                    Herbs    Type 1  2011-02-09 00:37:15 UTC
# 3          Tropical fruits    Type 1  2011-02-09 00:37:15 UTC
# 4  Onion-family vegetables    Type 1  2011-02-09 00:37:15 UTC
#
#                 updated_at creator_id updater_id export_to_afcdb  category  \
# 0  2017-06-27 17:13:48 UTC                     2           FALSE  specific
# 1  2017-03-20 21:26:22 UTC                                 FALSE  specific
# 2  2015-10-02 21:24:39 UTC                                 FALSE  specific
# 3  2017-03-20 21:26:22 UTC                                 FALSE  specific
# 4  2017-03-20 21:26:22 UTC                                 FALSE  specific
#
#   ncbi_taxonomy_id export_to_foodb
# 0           357850            TRUE
# 1          1216010            TRUE
# 2                             TRUE
# 3             3625            TRUE
# 4             4678            TRUE
#
# [5 rows x 22 columns]

# %%
foods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 22 columns):
# id                      907 non-null object
# name                    907 non-null object
# name_scientific         907 non-null object
# description             907 non-null object
# itis_id                 907 non-null object
# wikipedia_id            907 non-null object
# wikipedia_id_img        907 non-null object
# picture_content_type    907 non-null object
# picture_file_size       907 non-null object
# picture_updated_at      907 non-null object
# legacy_id               907 non-null object
# food_group              907 non-null object
# food_subgroup           907 non-null object
# food_type               907 non-null object
# created_at              907 non-null object
# updated_at              907 non-null object
# creator_id              907 non-null object
# updater_id              907 non-null object
# export_to_afcdb         907 non-null object
# category                907 non-null object
# ncbi_taxonomy_id        907 non-null object
# export_to_foodb         907 non-null object
# dtypes: object(22)
# memory usage: 156.0+ KB

# %% [markdown]
# Columns to drop:
#
# picture_updated_at
#
# created_at
#
# updated_at
#
# creator_id
#
# updater_id
#
# export_to_afcdb
#
# export_to_foodb

# %%
foods.shape
# Out:
# (907, 22)

# %%
foods['name'].value_counts().sum(), foods['name'].value_counts().sum(), foods['id'].value_counts().sum()
# Out:
# (907, 907, 907)

# %% [markdown]
# ### There are 907 foods in the database.

# %%
tables_columns['foods']
# Out:
# ['id',
#  'name',
#  'name_scientific',
#  'description',
#  'itis_id',
#  'wikipedia_id',
#  'wikipedia_id_img',
#  'picture_content_type',
#  'picture_file_size',
#  'picture_updated_at',
#  'legacy_id',
#  'food_group',
#  'food_subgroup',
#  'food_type',
#  'created_at',
#  'updated_at',
#  'creator_id',
#  'updater_id',
#  'export_to_afcdb',
#  'category',
#  'ncbi_taxonomy_id',
#  'export_to_foodb']

# %%
#alterante for food subgroup valuecounts
#pd.read_sql_query('''SELECT f.food_subgroup, 
#                        COUNT(f.name) foods
 #                       FROM foods f
 #                       GROUP BY f.food_subgroup
  #                      ORDER BY foods DESC
  #                  ;''', engine)

# %% [markdown]
# ### Investigating Type 1 and Type 2

# %%
pd.read_sql_query('''SELECT f.food_subgroup, 
                        COUNT(f.food_subgroup) subgroup
                        FROM foods f
                        WHERE f.food_type == 'Type 1'
                        GROUP BY f.food_subgroup
                    ;''', engine)
# Out:
# 2019-03-12 19:13:32,229 INFO sqlalchemy.engine.base.Engine SELECT f.food_subgroup,
#                         COUNT(f.food_subgroup) subgroup
#                         FROM foods f
#                         WHERE f.food_type == 'Type 1'
#                         GROUP BY f.food_subgroup
#                     ;
# 2019-03-12 19:13:32,230 INFO sqlalchemy.engine.base.Engine ()
#               food_subgroup  subgroup
# 0                Amphibians         1
# 1                     Beans        14
# 2                   Berries        55
# 3                   Bovines         4
# 4                  Cabbages        20
# 5                    Caprae         1
# 6                   Cereals        18
# 7                 Cetaceans         3
# 8                    Citrus         8
# 9                     Cocoa         1
# 10                   Coffee         3
# 11              Crustaceans        11
# 12                   Drupes         9
# 13                  Equines         1
# 14                   Fishes       110
# 15         Fruit vegetables        19
# 16                   Gourds        16
# 17              Herbal teas         2
# 18                    Herbs        61
# 19               Lagomorphs         3
# 20          Leaf vegetables        19
# 21                  Lentils         1
# 22               Marsupials         1
# 23                 Mollusks        17
# 24                Mushrooms         9
# 25                     Nuts        25
# 26            Oilseed crops        15
# 27  Onion-family vegetables         6
# 28      Other aquatic foods         4
# 29             Other fruits         3
# 30            Other mammals         4
# 31             Other pulses         2
# 32              Other seeds         7
# 33         Other vegetables        12
# 34                     Ovis         1
# 35                     Peas         8
# 36                Pinnipeds         6
# 37                    Pomes         6
# 38                  Poultry        15
# 39                  Rodents         4
# 40          Root vegetables        23
# 41                  Seaweed         8
# 42         Shoot vegetables         5
# 43                      Soy         1
# 44                   Spices        23
# 45         Stalk vegetables         3
# 46                    Swine         2
# 47                     Teas         1
# 48          Tropical fruits        43
# 49                   Tubers         8
# 50                  Venison         6

# %%
pd.read_sql_query('''SELECT f.food_subgroup, 
                        COUNT(f.food_subgroup) subgroup
                        FROM foods f
                        WHERE f.food_type == 'Type 2'
                        GROUP BY f.food_subgroup
                    ;''', engine)
# Out:
# 2019-03-12 19:14:06,827 INFO sqlalchemy.engine.base.Engine SELECT f.food_subgroup,
#                         COUNT(f.food_subgroup) subgroup
#                         FROM foods f
#                         WHERE f.food_type == 'Type 2'
#                         GROUP BY f.food_subgroup
#                     ;
# 2019-03-12 19:14:06,830 INFO sqlalchemy.engine.base.Engine ()
#               food_subgroup  subgroup
# 0       Alcoholic beverages         2
# 1          American cuisine         3
# 2               Animal fats         4
# 3             Asian cuisine         2
# 4                Baby foods         1
# 5              Baking goods        13
# 6            Berber cuisine         1
# 7            Bread products         1
# 8                   Candies         8
# 9           Cereal products         8
# 10           Cocoa products         6
# 11          Coffee products         1
# 12               Condiments         4
# 13                 Desserts         7
# 14      Distilled beverages         6
# 15                   Doughs         2
# 16                Dressings         1
# 17      Fermented beverages         6
# 18  Fermented milk products         4
# 19          Fermented milks         3
# 20            Fish products         1
# 21              Flat breads         6
# 22          Fortified wines         5
# 23          Frozen desserts         4
# 24           Fruit products         3
# 25                   Gourds         1
# 26              Ground meat         5
# 27  Herb and spice mixtures         1
# 28           Jewish cuisine         1
# 29   Latin American cuisine         4
# ..                      ...       ...
# 33          Mexican cuisine         4
# 34            Milk desserts         2
# 35    Nutritional beverages         2
# 36                     Nuts         1
# 37            Oilseed crops         1
# 38      Other aquatic foods         1
# 39          Other beverages         6
# 40             Other breads         2
# 41    Other confectioneries         6
# 42             Other dishes        13
# 43      Other milk products         8
# 44             Pasta dishes         4
# 45            Potato dishes         3
# 46                      Roe         1
# 47               Sandwiches         6
# 48                   Sauces         1
# 49               Seasonings         3
# 50              Snack foods         8
# 51             Soy products         8
# 52                  Spreads         2
# 53              Substitutes         6
# 54                   Sugars         1
# 55             Sweet breads         1
# 56          Tex-Mex cuisine         4
# 57             Unclassified         1
# 58        Unfermented milks         7
# 59           Vegetable fats         3
# 60       Vegetable products         1
# 61                   Waters         1
# 62                 Wrappers         4
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Type 1 looks like unprocessed or unprepared foods. Type 2 foods are processed or prepared.

# %%
#foods[foods['food_subgroup'] == 'Marsupials']

# %%
#to drop: id 694 (subgroup Unclassified)
#id 685 (subgroup waters)

# %% [markdown]
# ### Investigating NCBI Taxonomy ID

# %%
#Says no NA values but I see some in the head
foods['ncbi_taxonomy_id'].isna().sum()
# Out:
# 0

# %%
foods['ncbi_taxonomy_id'].value_counts()b
# Out:
#            276
# 4072         6
# 3885         3
# 13427        3
# 135518       2
# 41679        2
# 4682         2
# 183260       2
# 190544       2
# 4679         2
# 3661         2
# 138011       2
# 37656        2
# 3714         2
# 16718        1
# 357850       1
# 34256        1
# 8113         1
# 66014        1
# 888065       1
# 9031         1
# 59166        1
# 37796        1
# 6565         1
# 9721         1
# 7797         1
# 167592       1
# 109171       1
# 2763         1
# 225387       1
#           ...
# 49390        1
# 33637        1
# 195615       1
# 397755       1
# 36066        1
# 8112         1
# 106975       1
# 36181        1
# 42229        1
# 9103         1
# 4071         1
# 334483       1
# 4558         1
# 32219        1
# 6763         1
# 29780        1
# 1042646      1
# 4039         1
# 119950       1
# 7935         1
# 8017         1
# 3891         1
# 13493        1
# 30850        1
# 485725       1
# 103480       1
# 24663        1
# 403101       1
# 4681         1
# 66656        1
# Name: ncbi_taxonomy_id, Length: 613, dtype: int64

# %%
foods[foods['ncbi_taxonomy_id'] == '4072']
# Out:
#       id                      name  name_scientific  \
# 39    40        Pepper (C. annuum)  Capsicum annuum
# 891  909         Green bell pepper  Capsicum annuum
# 892  910        Yellow bell pepper  Capsicum annuum
# 893  911        Orange bell pepper  Capsicum annuum
# 894  912           Red bell pepper  Capsicum annuum
# 895  913  Italian sweet red pepper  Capsicum annuum
#
#                                            description itis_id  \
# 39   <i>Capsicum annuum</i> is a domesticated speci...   30492
# 891  Green bell peppers are members of the domestic...   30492
# 892  Yellow bell peppers are members of the domesti...   30492
# 893  Orange bell peppers are members of the domesti...   30492
# 894  Red bell peppers are members of the domesticat...   30492
# 895  The Italian sweet pepper is a variety of the s...
#
#              wikipedia_id                 wikipedia_id_img  \
# 39        Capsicum_annuum                           40.jpg
# 891       Capsicum_annuum      428px-Green-Bell-Pepper.jpg
# 892       Capsicum_annuum         bell_pepper_yellow_2.png
# 893       Capsicum_annuum        orange-bell-pepper-02.jpg
# 894       Capsicum_annuum              red-bell-pepper.jpg
# 895  Italian sweet pepper  939px-Italian_sweet_peppers.jpg
#
#     picture_content_type picture_file_size       picture_updated_at  \
# 39            image/jpeg             45222  2012-04-20 09:37:27 UTC
# 891           image/jpeg             26784  2015-02-26 18:37:27 UTC
# 892            image/png             25165  2015-02-26 18:42:45 UTC
# 893           image/jpeg              6881  2015-02-26 18:44:18 UTC
# 894           image/jpeg             76376  2015-02-26 18:47:15 UTC
# 895           image/jpeg            124244  2015-02-26 18:54:22 UTC
#
#           ...           food_subgroup food_type               created_at  \
# 39        ...        Fruit vegetables    Type 1  2011-02-09 00:37:17 UTC
# 891       ...        Fruit vegetables    Type 1  2015-02-26 18:37:27 UTC
# 892       ...        Fruit vegetables    Type 1  2015-02-26 18:42:45 UTC
# 893       ...        Fruit vegetables    Type 1  2015-02-26 18:44:18 UTC
# 894       ...        Fruit vegetables    Type 1  2015-02-26 18:47:16 UTC
# 895       ...        Fruit vegetables    Type 1  2015-02-26 18:54:23 UTC
#
#                   updated_at creator_id updater_id export_to_afcdb  category  \
# 39   2017-03-20 21:26:23 UTC                     2           FALSE  specific
# 891  2017-03-20 21:26:33 UTC                                  TRUE  specific
# 892  2017-03-20 21:26:34 UTC                                  TRUE  specific
# 893  2017-03-20 21:26:34 UTC                                  TRUE  specific
# 894  2017-03-20 21:26:34 UTC                                  TRUE  specific
# 895  2017-03-20 21:26:34 UTC                                  TRUE  specific
#
#     ncbi_taxonomy_id export_to_foodb
# 39              4072            TRUE
# 891             4072            TRUE
# 892             4072            TRUE
# 893             4072            TRUE
# 894             4072            TRUE
# 895             4072            TRUE
#
# [6 rows x 22 columns]

# %% [markdown]
# ### Some ncbis are repeated but all foods seem to have one.

# %% [markdown]
# ### Investigating Category

# %%
foods['category'].value_counts()
# Out:
# specific    881
# generic      26
# Name: category, dtype: int64

# %%
generics = list(foods['name'][foods['category'] == 'generic'])
subgroups = list(set(foods['food_subgroup']))

# %%
len(generics)
# Out:
# 26

# %%
generic_subgroups = []

for sub in subgroups:
    if any(generic in sub for generic in generics):
        generic_subgroups.append(sub)

# %%
len(set(generic_subgroups))
# Out:
# 27

# %% [markdown]
# ### The "generic" category is just 26 of the subgroups with a bit more information about each.

# %% [markdown]
# [(Back to top)](#top)
#
# # Exploratory data analysis

# %% [markdown]
# <a id = 'eda_enzymes'></a>

# %% [markdown]
# ## Enzymes table

# %%
enzymes = pd.read_sql_query('''SELECT e.* 
                            FROM enzymes e
                            ;''', engine)
# Out:
# 2019-03-16 12:41:30,408 INFO sqlalchemy.engine.base.Engine SELECT e.*
#                             FROM enzymes e
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT e.*
#                             FROM enzymes e
#                             ;
# 2019-03-16 12:41:30,408 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
enzymes.shape
# Out:
# (1744, 32)

# %%
enzymes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1744 entries, 0 to 1743
# Data columns (total 32 columns):
# id                       1744 non-null object
# name                     1744 non-null object
# gene_name                1744 non-null object
# description              1744 non-null object
# go_classification        1744 non-null object
# general_function         1744 non-null object
# specific_function        1744 non-null object
# pathway                  1744 non-null object
# reaction                 1744 non-null object
# cellular_location        1744 non-null object
# signals                  1744 non-null object
# transmembrane_regions    1744 non-null object
# molecular_weight         1744 non-null object
# theoretical_pi           1744 non-null object
# locus                    1744 non-null object
# chromosome               1744 non-null object
# uniprot_name             1744 non-null object
# uniprot_id               1744 non-null object
# pdb_id                   1744 non-null object
# genbank_protein_id       1744 non-null object
# genbank_gene_id          1744 non-null object
# genecard_id              1744 non-null object
# genatlas_id              1744 non-null object
# hgnc_id                  1744 non-null object
# hprd_id                  1744 non-null object
# organism                 1744 non-null object
# general_citations        1744 non-null object
# comments                 1744 non-null object
# creator_id               1744 non-null object
# updater_id               1744 non-null object
# created_at               1744 non-null object
# updated_at               1744 non-null object
# dtypes: object(32)
# memory usage: 436.1+ KB

# %%
enzymes['name'].value_counts().sum(), enzymes['gene_name'].value_counts().sum()
# Out:
# (1744, 1744)

# %% [markdown]
# ### 1744 unique names and gene names. Linked to compounds.

# %% [markdown]
# ### How many null values?

# %%
enzymes.head(3)
# Out:
#   id                              name gene_name description  \
# 0  1  UDP-glucuronosyltransferase 2B28   UGT2B28        NULL
# 1  2            Estrogen receptor beta      ESR2        NULL
# 2  3   UDP-glucuronosyltransferase 2B4    UGT2B4        NULL
#
#   go_classification general_function specific_function pathway reaction  \
# 0              NULL             NULL              NULL    NULL     NULL
# 1              NULL             NULL              NULL    NULL     NULL
# 2              NULL             NULL              NULL    NULL     NULL
#
#   cellular_location         ...          genatlas_id hgnc_id hprd_id organism  \
# 0              NULL         ...                 NULL    NULL    NULL     NULL
# 1              NULL         ...                 NULL    NULL    NULL     NULL
# 2              NULL         ...                 NULL    NULL    NULL     NULL
#
#   general_citations comments creator_id updater_id           created_at  \
# 0              NULL     NULL       NULL       NULL  2015-02-23 22:40:56
# 1              NULL     NULL       NULL       NULL  2015-02-23 22:40:57
# 2              NULL     NULL       NULL       NULL  2015-02-23 22:40:57
#
#             updated_at
# 0  2015-02-23 22:40:56
# 1  2015-02-23 22:40:57
# 2  2015-02-23 22:40:57
#
# [3 rows x 32 columns]

# %%
null_enzyme_descriptions = enzymes['description'] == 'NULL'

# %%
null_enzyme_descriptions.sum()
# Out:
# 1744

# %%
enzymes[enzymes['description'] == 'NULL'].shape
# Out:
# (1744, 32)

# %%
enzymes[enzymes['go_classification'] == 'NULL'].shape
# Out:
# (1744, 32)

# %%
enzymes[enzymes['general_function'] == 'NULL'].shape
# Out:
# (1744, 32)

# %%
enzymes[enzymes['specific_function'] == 'NULL'].shape
# Out:
# (1744, 32)

# %%
for column in enzymes.columns:
    print(column, enzymes[enzymes[column] == 'NULL'].shape[0])
# Out:
# id 0
# name 0
# gene_name 0
# description 1744
# go_classification 1744
# general_function 1744
# specific_function 1744
# pathway 1744
# reaction 1744
# cellular_location 1744
# signals 1744
# transmembrane_regions 1744
# molecular_weight 1744
# theoretical_pi 1744
# locus 1744
# chromosome 1744
# uniprot_name 1744
# uniprot_id 0
# pdb_id 1744
# genbank_protein_id 1744
# genbank_gene_id 1744
# genecard_id 1744
# genatlas_id 1744
# hgnc_id 1744
# hprd_id 1744
# organism 1744
# general_citations 1744
# comments 1744
# creator_id 1744
# updater_id 1744
# created_at 0
# updated_at 0

# %% [markdown]
# ### Drop all columns except id, name, and gene_name.

# %%
enzymes['gene_name'].value_counts().sum()
# Out:
# 1744

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory data analysis

# %% [markdown]
# <a id = 'eda_flavors'></a>

# %% [markdown]
# ## flavors table

# %%
flavors = pd.read_sql_query('''SELECT fl.* 
                            FROM flavors fl
                            ;''', engine)
# Out:
# 2019-03-16 13:00:30,081 INFO sqlalchemy.engine.base.Engine SELECT fl.*
#                             FROM flavors fl
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT fl.*
#                             FROM flavors fl
#                             ;
# 2019-03-16 13:00:30,083 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
flavors.head()
# Out:
#   id         name flavor_group category           created_at  \
# 0  1       celery    vegetable     odor  2011-10-02 06:10:04
# 1  2         corn    vegetable     odor  2011-10-02 06:10:04
# 2  3     cucumber    vegetable     odor  2011-10-02 06:10:04
# 3  4  horseradish    vegetable     odor  2011-10-02 06:10:05
# 4  5    vegetable    vegetable     odor  2011-10-02 06:10:05
#
#             updated_at creator_id updater_id
# 0  2011-10-02 06:10:04       NULL       NULL
# 1  2011-10-02 06:10:04       NULL       NULL
# 2  2011-10-02 06:10:04       NULL       NULL
# 3  2011-10-02 06:10:05       NULL       NULL
# 4  2011-10-02 06:10:05       NULL       NULL

# %%
flavors['flavor_group'].value_counts()
# Out:
# NULL             743
# fruity            24
# floral            14
# balsamic          10
# vegetable          8
# fatty              7
# wine_like          5
# herbaceous         5
# citrus             5
# nutty              5
# woody              4
# chemical           3
# meaty              3
# green              3
# earthy             3
# spicy              2
# musky              1
# tobacco            1
# smoky              1
# minty              1
# medicinal          1
# camphoraceous      1
# mossy              1
# fishy              1
# pepper             1
# seedy              1
# animal             1
# soapy              1
# Name: flavor_group, dtype: int64

# %%
flavors['category'].value_counts()
# Out:
# odor    856
# Name: category, dtype: int64

# %% [markdown]
# ### Drop all columns except id, name, and flavor_group
# ### Will have to see later how compounds are connected to these descriptions of flavor. Disappointed that there are 856 unique descriptors ('name') and very few useful flavor_group designations.

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory Data Analysis

# %% [markdown]
# <a id = 'eda_health_effects'></a>

# %% [markdown]
# ## Health effects table

# %%
health_effects = pd.read_sql_query('''SELECT he.* 
                            FROM health_effects he
                            ;''', engine)
# Out:
# 2019-03-16 13:25:32,755 INFO sqlalchemy.engine.base.Engine SELECT he.*
#                             FROM health_effects he
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT he.*
#                             FROM health_effects he
#                             ;
# 2019-03-16 13:25:32,755 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
health_effects.shape
# Out:
# (1435, 10)

# %%
health_effects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 10 columns):
# id                  1435 non-null object
# name                1435 non-null object
# description         1435 non-null object
# chebi_name          1435 non-null object
# chebi_id            1435 non-null object
# created_at          1435 non-null object
# updated_at          1435 non-null object
# creator_id          1435 non-null object
# updater_id          1435 non-null object
# chebi_definition    1435 non-null object
# dtypes: object(10)
# memory usage: 112.2+ KB

# %%
health_effects.head()
# Out:
#   id                                           name  \
# 0  1                                  (+)-inotropic
# 1  2                               (-)-chronotropic
# 2  3                                  (-)-inotropic
# 3  4  11beta-hydroxysteroid-dehydrogenase inhibitor
# 4  5                      12-lipoxygenase inhibitor
#
#                                          description        chebi_name  \
# 0  An agent that alters the force or energy of mu...              NULL
# 1  An agent that may change theÂ heartÂ rate by a...              NULL
# 2  An agent that alters the force or energy of mu...              NULL
# 3                                               NULL  enzyme inhibitor
# 4                                               NULL  enzyme inhibitor
#
#   chebi_id           created_at           updated_at creator_id updater_id  \
# 0     NULL  2012-04-10 10:05:13  2015-11-11 02:32:19       NULL       NULL
# 1     NULL  2012-04-10 10:05:13  2015-11-11 02:32:19       NULL       NULL
# 2     NULL  2012-04-10 10:05:13  2015-11-11 02:32:19       NULL       NULL
# 3    23924  2012-04-10 10:05:13  2015-10-27 17:47:35       NULL       NULL
# 4    23924  2012-04-10 10:05:13  2015-10-27 17:47:36       NULL       NULL
#
#                                     chebi_definition
# 0                                               NULL
# 1                                               NULL
# 2                                               NULL
# 3  A compound or agent that combines with an enzy...
# 4  A compound or agent that combines with an enzy...

# %%
for column in health_effects.columns:
    print(column, health_effects[health_effects[column] != 'NULL'].shape[0])
# Out:
# id 1435
# name 1435
# description 619
# chebi_name 710
# chebi_id 710
# created_at 1435
# updated_at 1435
# creator_id 0
# updater_id 0
# chebi_definition 698

# %%
#Are the rows with a non-null chebi_id the same as the rows with a non-null chebi_name?
chebi_ids = health_effects[health_effects['chebi_id'] != 'NULL']

# %%
chebi_name = health_effects[health_effects['chebi_name'] != 'NULL']

# %%
trues = chebi_ids == chebi_name

# %% [markdown]
# ### Drop created_at, updated_at, creator_id, updater_id

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory Data Analysis

# %% [markdown]
# <a id = 'eda_nutrients'></a>

# %% [markdown]
# ## Nutrients table

# %%
nutrients = pd.read_sql_query('''SELECT n.* 
                            FROM nutrients n
                            ;''', engine)
# Out:
# 2019-03-15 13:29:47,268 INFO sqlalchemy.engine.base.Engine SELECT n.*
#                             FROM nutrients n
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT n.*
#                             FROM nutrients n
#                             ;
# 2019-03-15 13:29:47,268 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
nutrients.head()
# Out:
#   id legacy_id      type  public_id             name export state  \
# 0  1     10930  Nutrient  FDBN00001              Fat      0  NULL
# 1  2     10946  Nutrient  FDBN00002         Proteins      0  NULL
# 2  3     16037  Nutrient  FDBN00003     Carbohydrate      0  NULL
# 3  4     23404  Nutrient  FDBN00004      Fatty acids      0  NULL
# 4  5     11134  Nutrient  FDBN00005  Fiber (dietary)      0  NULL
#
#   annotation_quality                                        description  \
# 0                low                                               NULL
# 1                low                                               NULL
# 2                low  Carbohydrates (or saccharides) are organic com...
# 3                low                                               NULL
# 4                low                                               NULL
#
#    wikipedia_id         ...          eafus_id dfc_name compound_source  \
# 0          NULL         ...              NULL     NULL            DUKE
# 1          NULL         ...              NULL     NULL            DUKE
# 2  Carbohydrate         ...              NULL     NULL            DUKE
# 3          NULL         ...              1335     NULL           EAFUS
# 4          NULL         ...              NULL     NULL            DUKE
#
#   metabolism synthesis_citations general_citations creator_id updater_id  \
# 0       NULL                NULL              NULL       NULL       NULL
# 1       NULL                NULL              NULL       NULL       NULL
# 2       NULL                NULL              NULL       NULL       NULL
# 3       NULL                NULL              NULL       NULL       NULL
# 4       NULL                NULL              NULL       NULL       NULL
#
#             created_at           updated_at
# 0  2014-11-05 13:42:10  2014-11-05 13:42:10
# 1  2014-11-05 13:42:15  2014-11-05 13:42:15
# 2  2014-11-05 13:44:06  2014-11-05 13:44:06
# 3  2014-11-05 13:46:00  2014-11-05 13:46:00
# 4  2014-11-05 13:47:36  2014-11-05 13:47:36
#
# [5 rows x 23 columns]

# %%
for column in nutrients.columns:
    print(column, nutrients[nutrients[column] == 'NULL'].shape[0])
# Out:
# id 0
# legacy_id 0
# type 0
# public_id 0
# name 0
# export 0
# state 38
# annotation_quality 0
# description 37
# wikipedia_id 37
# comments 38
# dfc_id 38
# duke_id 33
# eafus_id 37
# dfc_name 38
# compound_source 0
# metabolism 38
# synthesis_citations 38
# general_citations 38
# creator_id 38
# updater_id 38
# created_at 0
# updated_at 0

# %% [markdown]
# ### Drop whole table.

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory data analysis

# %% [markdown]
# <a id = 'eda_pathways'></a>

# %% [markdown]
# ## Pathways table

# %%
pathways = pd.read_sql_query('''SELECT pa.* 
                            FROM pathways pa
                            ;''', engine)
# Out:
# 2019-03-16 13:39:36,133 INFO sqlalchemy.engine.base.Engine SELECT pa.*
#                             FROM pathways pa
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT pa.*
#                             FROM pathways pa
#                             ;
# 2019-03-16 13:39:36,134 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
pathways.head(20)
# Out:
#     id  smpdb_id kegg_map_id                                        name  \
# 0    1  SMP00006    map00350                         Tyrosine Metabolism
# 1    2  SMP00068    map00150            Androgen and Estrogen Metabolism
# 2    3  SMP00011    map00562                         Inositol Metabolism
# 3    4  SMP00462    map00562               Inositol Phosphate Metabolism
# 4    5  SMP00012    map00350                  Catecholamine Biosynthesis
# 5    6  SMP00008    map00360       Phenylalanine and Tyrosine Metabolism
# 6    7  SMP00019                               Transcription/Translation
# 7    8  SMP00028    map00232                         Caffeine Metabolism
# 8    9  SMP00037    map00310                          Lysine Degradation
# 9   10  SMP00016    map00640                       Propanoate Metabolism
# 10  11  SMP00032    map00280  Valine, Leucine and Isoleucine Degradation
# 11  12  SMP00066    map00780                           Biotin Metabolism
# 12  13  SMP00465                                     Carnitine Synthesis
# 13  14  SMP00055    map00250                          Alanine Metabolism
# 14  15  SMP00009    map00910                           Ammonia Recycling
# 15  16  SMP00035    map00120                      Bile Acid Biosynthesis
# 16  17  SMP00015    map00480                      Glutathione Metabolism
# 17  18  SMP00004    map00260               Glycine and Serine Metabolism
# 18  19  SMP00033    map00270                       Methionine Metabolism
# 19  20  SMP00024    map00860                        Porphyrin Metabolism
#
#              created_at           updated_at
# 0   2015-02-23 22:40:48  2015-02-23 22:40:48
# 1   2015-02-23 22:40:58  2015-02-23 22:40:58
# 2   2015-02-23 22:41:14  2015-02-23 22:41:14
# 3   2015-02-23 22:41:14  2015-02-23 22:41:14
# 4   2015-02-23 22:42:38  2015-02-23 22:42:38
# 5   2015-02-23 22:42:38  2015-02-23 22:42:38
# 6   2015-02-23 22:42:38  2015-02-23 22:42:38
# 7   2015-02-23 22:42:49  2015-02-23 22:42:49
# 8   2015-02-23 22:42:58  2015-02-23 22:42:58
# 9   2015-02-23 22:43:04  2015-02-23 22:43:04
# 10  2015-02-23 22:43:04  2015-02-23 22:43:04
# 11  2015-02-23 22:43:17  2015-02-23 22:43:17
# 12  2015-02-23 22:43:17  2015-02-23 22:43:17
# 13  2015-02-23 22:43:32  2015-02-23 22:43:32
# 14  2015-02-23 22:43:32  2015-02-23 22:43:32
# 15  2015-02-23 22:43:32  2015-02-23 22:43:32
# 16  2015-02-23 22:43:32  2015-02-23 22:43:32
# 17  2015-02-23 22:43:32  2015-02-23 22:43:32
# 18  2015-02-23 22:43:32  2015-02-23 22:43:32
# 19  2015-02-23 22:43:32  2015-02-23 22:43:32

# %% [markdown]
# ### Drop created_at, updated_at

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory data analysis

# %% [markdown]
# <a id = 'eda_ref'></a>

# %% [markdown]
# ## References table

# %%
references = pd.read_sql_query('''SELECT r.* 
                            FROM [references] r
                            ;''', engine)
# Out:
# 2019-03-15 13:42:27,331 INFO sqlalchemy.engine.base.Engine SELECT r.*
#                             FROM [references] r
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT r.*
#                             FROM [references] r
#                             ;
# 2019-03-15 13:42:27,333 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
table_names
# Out:
# ['compound_alternate_parents',
#  'compound_external_descriptors',
#  'compound_substituents',
#  'compound_synonyms',
#  'compounds',
#  'compounds_enzymes',
#  'compounds_flavors',
#  'compounds_health_effects',
#  'compounds_pathways',
#  'enzymes',
#  'flavors',
#  'food_taxonomies',
#  'foodcomex_compound_providers',
#  'foodcomex_compounds',
#  'foods',
#  'foods_copy',
#  'health_effects',
#  'nutrients',
#  'pathways',
#  'references']

# %%
references.head()
# Out:
#   id ref_type                                               text pubmed_id  \
# 0  1  general  Yannai, Shmuel. (2004) Dictionary of food comp...
# 1  2  general  Neveu V, Perez-Jimenez J, Vos F, Crespy V, du ...
# 2  3  general  Neveu V, Perez-Jimenez J, Vos F, Crespy V, du ...
# 3  4  general  de Villiers A, Vanhoenacker G, Majek P, Sandra...
# 4  5  general  Neveu V, Perez-Jimenez J, Vos F, Crespy V, du ...
#
#   link title creator_id updater_id           created_at           updated_at  \
# 0                  NULL       NULL  2015-02-23 22:39:47  2015-02-23 22:39:47
# 1                  NULL       NULL  2015-02-23 22:39:50  2015-02-23 22:39:50
# 2                  NULL       NULL  2015-02-23 22:39:50  2015-02-23 22:39:50
# 3                  NULL       NULL  2015-02-23 22:39:52  2015-02-23 22:39:52
# 4                  NULL       NULL  2015-02-23 22:39:54  2015-02-23 22:39:54
#
#   source_id source_type
# 0         1    Compound
# 1        22    Compound
# 2        48    Compound
# 3        52    Compound
# 4        59    Compound

# %%
references.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31791 entries, 0 to 31790
# Data columns (total 12 columns):
# id             31791 non-null object
# ref_type       31791 non-null object
# text           31791 non-null object
# pubmed_id      31791 non-null object
# link           31791 non-null object
# title          31791 non-null object
# creator_id     31791 non-null object
# updater_id     31791 non-null object
# created_at     31791 non-null object
# updated_at     31791 non-null object
# source_id      31791 non-null object
# source_type    31791 non-null object
# dtypes: object(12)
# memory usage: 2.9+ MB

# %% [markdown]
# ### Drop table.

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory data analysis

# %% [markdown]
# <a id = 'eda_food_tax'></a>

# %% [markdown]
# ## food taxonomies table

# %%
food_taxonomies = pd.read_sql_query('''SELECT ft.* 
                            FROM food_taxonomies ft
                            ;''', engine)
# Out:
# 2019-03-15 13:45:43,423 INFO sqlalchemy.engine.base.Engine SELECT ft.*
#                             FROM food_taxonomies ft
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT ft.*
#                             FROM food_taxonomies ft
#                             ;
# 2019-03-15 13:45:43,425 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
food_taxonomies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919 entries, 0 to 918
# Data columns (total 7 columns):
# id                      919 non-null object
# food_id                 919 non-null object
# ncbi_taxonomy_id        919 non-null object
# classification_name     919 non-null object
# classification_order    919 non-null object
# created_at              919 non-null object
# updated_at              919 non-null object
# dtypes: object(7)
# memory usage: 50.3+ KB

# %%
food_taxonomies.head()
# Out:
#   id food_id ncbi_taxonomy_id classification_name classification_order  \
# 0  1       1           357850         \Eukaryota\                    1
# 1  2       1           357850     \Viridiplantae\                    2
# 2  3       1           357850      \Streptophyta\                    3
# 3  4       1           357850       \Embryophyta\                    4
# 4  5       1           357850      \Tracheophyta\                    5
#
#             created_at           updated_at
# 0  2017-03-29 18:35:53  2017-03-29 18:35:53
# 1  2017-03-29 18:35:53  2017-03-29 18:35:53
# 2  2017-03-29 18:35:53  2017-03-29 18:35:53
# 3  2017-03-29 18:35:53  2017-03-29 18:35:53
# 4  2017-03-29 18:35:53  2017-03-29 18:35:53

# %%
food_taxonomies[food_taxonomies['classification_order'] == '16']
# Out:
#       id food_id ncbi_taxonomy_id     classification_name  \
# 15    16       1           357850     \apioid superclade\
# 33    34      19            72341           \Anthemideae\
# 51    52      37             3821            \Phaseoleae\
# 68    69      54             2708                \Citrus\
# 84    85      70            66014            \Cymbopogon\
# 100  101      86             4232  \Heliantheae alliance\
# 118  119     104             3869             \Genisteae\
# 135  136     121             4146                  \Olea\
# 151  152     137           271192     \apioid superclade\
# 182  183     168            49988              \Mentheae\
# 199  200     185           172266                 \Tilia\
# 215  216     201            87088            \Phaseoleae\
# 232  233     218           176259             \Vaccinium\
# 263  264     249           941588     \apioid superclade\
# 356  357     342            80720               \Gadidae\
# 417  418     403           225387         \Hexagrammidae\
# 434  435     420             3728               \Sinapis\
# 450  451     436            40321             \Capsiceae\
# 480  481     466            59499    \Rosoideae unplaced\
# 541  542     527             8267          \Hippoglossus\
# 613  614     599             8101         \Cyclopteridae\
# 680  681     748           183260              \Hibiscus\
# 704  705     786            61886               \Cucumis\
# 720  721     797           138011              \Brassica\
# 749  750     799           108881             \Theobroma\
# 820  821     814           227725              \Solaneae\
# 837  838     849           153159  \Heliantheae alliance\
# 871  872     879           113210             \Capsiceae\
# 901  902     887             3705              \Brassica\
# 917  918     909             4072             \Capsiceae\
#
#     classification_order           created_at           updated_at
# 15                    16  2017-03-29 18:35:53  2017-03-29 18:35:53
# 33                    16  2017-03-29 18:35:54  2017-03-29 18:35:54
# 51                    16  2017-03-29 18:35:54  2017-03-29 18:35:54
# 68                    16  2017-03-29 18:35:54  2017-03-29 18:35:54
# 84                    16  2017-03-29 18:35:54  2017-03-29 18:35:54
# 100                   16  2017-03-29 18:35:55  2017-03-29 18:35:55
# 118                   16  2017-03-29 18:35:55  2017-03-29 18:35:55
# 135                   16  2017-03-29 18:35:55  2017-03-29 18:35:55
# 151                   16  2017-03-29 18:35:56  2017-03-29 18:35:56
# 182                   16  2017-03-29 18:35:56  2017-03-29 18:35:56
# 199                   16  2017-03-29 18:35:56  2017-03-29 18:35:56
# 215                   16  2017-03-29 18:35:57  2017-03-29 18:35:57
# 232                   16  2017-03-29 18:35:57  2017-03-29 18:35:57
# 263                   16  2017-03-29 18:35:58  2017-03-29 18:35:58
# 356                   16  2017-03-29 18:35:59  2017-03-29 18:35:59
# 417                   16  2017-03-29 18:36:00  2017-03-29 18:36:00
# 434                   16  2017-03-29 18:36:00  2017-03-29 18:36:00
# 450                   16  2017-03-29 18:36:00  2017-03-29 18:36:00
# 480                   16  2017-03-29 18:36:00  2017-03-29 18:36:00
# 541                   16  2017-03-29 18:36:01  2017-03-29 18:36:01
# 613                   16  2017-03-29 18:36:02  2017-03-29 18:36:02
# 680                   16  2017-03-29 18:36:03  2017-03-29 18:36:03
# 704                   16  2017-03-29 18:36:04  2017-03-29 18:36:04
# 720                   16  2017-03-29 18:36:04  2017-03-29 18:36:04
# 749                   16  2017-03-29 18:36:04  2017-03-29 18:36:04
# 820                   16  2017-03-29 18:36:05  2017-03-29 18:36:05
# 837                   16  2017-03-29 18:36:05  2017-03-29 18:36:05
# 871                   16  2017-03-29 18:36:05  2017-03-29 18:36:05
# 901                   16  2017-03-29 18:36:06  2017-03-29 18:36:06
# 917                   16  2017-03-29 18:36:06  2017-03-29 18:36:06

# %%
food_taxonomies['food_id'].value_counts()
# Out:
# 19     18
# 137    18
# 249    18
# 849    18
# 86     18
# 1      18
# 168    17
# 342    17
# 104    17
# 466    17
# 201    17
# 436    17
# 37     17
# 909    17
# 814    17
# 403    17
# 879    17
# 887    16
# 797    16
# 527    16
# 599    16
# 54     16
# 121    16
# 786    16
# 70     16
# 799    16
# 185    16
# 420    16
# 218    16
# 748    16
#        ..
# 388    15
# 483    15
# 359    15
# 316    15
# 723    15
# 622    15
# 513    14
# 801    14
# 726    14
# 374    14
# 302    14
# 571    14
# 585    14
# 267    13
# 453    13
# 880    13
# 289    13
# 155    13
# 548    13
# 798    13
# 802    11
# 331    11
# 863    11
# 561    10
# 280     9
# 756     8
# 617     5
# 861     5
# 544     5
# 615     2
# Name: food_id, Length: 64, dtype: int64

# %% [markdown]
# ### Disappointed to discover that the full taxonomy is apparently only available for 64 foods in the foods table.
#
# ### Could be better organized to have a column for each level of the taxonomy, and a row for each food_id.
#
# ### Drop id, created_at, updated_at.
#
# Keep food_id INTEGER foreign key, ncbi_taxonomy_id INTEGER, classification_name TEXT, classification_order INTEGER

# %% [markdown]
# <a id = 'test_query_ft'></a>

# %% [markdown]
# ### Test query for food taxonomies to see how they'll look

# %%
pd.read_sql_query('''SELECT f.name, f.name_scientific,
                            ft.classification_name, 
                            ft.classification_order
                        FROM food_taxonomies ft
                        JOIN foods f ON f.id == ft.food_id
                        WHERE ft.food_id == 756

                        ORDER BY ft.classification_order
                    ;''', engine)
# Out:
# 2019-03-15 14:18:28,726 INFO sqlalchemy.engine.base.Engine SELECT f.name, f.name_scientific,
#                             ft.classification_name,
#                             ft.classification_order
#                         FROM food_taxonomies ft
#                         JOIN foods f ON f.id == ft.food_id
#                         WHERE ft.food_id == 756
#
#                         ORDER BY ft.classification_order
#                     ;
# INFO:sqlalchemy.engine.base.Engine:SELECT f.name, f.name_scientific,
#                             ft.classification_name,
#                             ft.classification_order
#                         FROM food_taxonomies ft
#                         JOIN foods f ON f.id == ft.food_id
#                         WHERE ft.food_id == 756
#
#                         ORDER BY ft.classification_order
#                     ;
# 2019-03-15 14:18:28,736 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#                 name name_scientific classification_name  classification_order
# 0  Morchella (Morel)   Morchellaceae         \Eukaryota\                     1
# 1  Morchella (Morel)   Morchellaceae             \Fungi\                     2
# 2  Morchella (Morel)   Morchellaceae           \Dikarya\                     3
# 3  Morchella (Morel)   Morchellaceae        \Ascomycota\                     4
# 4  Morchella (Morel)   Morchellaceae    \Pezizomycotina\                     5
# 5  Morchella (Morel)   Morchellaceae     \Pezizomycetes\                     6
# 6  Morchella (Morel)   Morchellaceae         \Pezizales\                     7
# 7  Morchella (Morel)   Morchellaceae     \Morchellaceae\                     8

# %%
#TEST 
UPDATE food_taxonomies
SET (order_01) = (SELECT LAG (order_01) OVER (order_01)
FROM food_taxonomies
CASE food_id WHEN (LAG(food_id) OVER (food_id) == food_id);

# %%
#THIS WORKS
UPDATE food_taxonomies
SET order_02 = '\Viridiplantae\'
WHERE food_id = 1;

# %%
#THIS WORKS 
UPDATE food_taxonomies
SET order_03 = (SELECT lag ( order_03, 1) OVER (ORDER BY order_03)
				FROM food_taxonomies
				WHERE food_id = 1)
				
WHERE food_id = 1;b

# %%
## Runs but sets all rows to null

UPDATE food_taxonomies
SET order_03 = (SELECT 
					CASE order_03 WHEN (lag ( order_03, 1) OVER (ORDER BY order_03) != NULL)
						THEN lag ( order_03, 1) OVER (ORDER BY order_03)
					END
				FROM food_taxonomies
				WHERE food_id = 1)
WHERE food_id = 1;

# %%
## Runs but doesn't do anything to any row

UPDATE food_taxonomies
SET order_03 = (SELECT 
					CASE order_03 WHEN (lag ( order_03, 1) OVER (ORDER BY order_03) != NULL)
						THEN lag ( order_03, 1) OVER (ORDER BY order_03)
					END
				FROM food_taxonomies
				WHERE food_id = 1)
WHERE food_id = 1
AND order_03 = NULL;

# %%
# Runs but doesn't do anything to any row
UPDATE food_taxonomies
SET order_03 = (SELECT lag ( order_03, 1) OVER (ORDER BY order_03)
				FROM food_taxonomies
				WHERE food_id = 1)
WHERE food_id = 1
AND order_03 = NULL;

# %%
#Sets all rows to Null
UPDATE food_taxonomies
SET order_03 = (SELECT CASE order_03
				WHEN order_03 == NULL
				THEN lag ( order_03, 1) OVER (ORDER BY order_03)
				END
				FROM food_taxonomies);

# %%
UPDATE food_taxonomies
SET order_03 = (SELECT CASE order_03
				WHEN order_03 == NULL
					AND (lag ( order_03, 1) OVER (ORDER BY order_03)) != NULL
				THEN lag ( order_03, 1) OVER (ORDER BY order_03)
				END
				FROM food_taxonomies);

# %%
#BREAKTHROUGH. Doesn't erase rows with data. Seems to set 845 out of 919 rows to null.
UPDATE food_taxonomies
SET order_03 = (SELECT lag ( order_03, 1) OVER (ORDER BY order_03)
				FROM food_taxonomies)
WHERE order_03 IS NULL;

# %%
#Does same as above.
#It knows to skip the row is isn't null, but it's inputting a Null value instead of the lag value.
UPDATE food_taxonomies
SET order_03 = (SELECT CASE order_03
					WHEN (lag ( order_03, 1) OVER (ORDER BY order_03)) IS NOT NULL
					THEN lag ( order_03, 1) OVER (ORDER BY order_03)
					END
					FROM food_taxonomies)
WHERE order_03 IS NULL;

# %%
Should I test just getting a lag value?

# %%
#This returns them but in the wrong order
SELECT order_03, lag ( order_03, 1, NULL) OVER (ORDER BY order_03)
FROM food_taxonomies
WHERE order_03 IS NOT NULL

# %%
#This returns them in the right order
SELECT lag ( order_03, 1, NULL) OVER (ORDER BY food_id)
FROM food_taxonomies
WHERE order_03 IS NOT NULL

# %%
[first line is null]
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Lophotrochozoa\
\Streptophyta\
\Chordata\
\Chordata\
\Streptophyta\
\Chordata\
\Ecdysozoa\
\Streptophyta\
\Chordata\
\Chordata\
\Streptophyta\
\Streptophyta\
\Chordata\
\Streptophyta\
\Chordata\
\Chordata\
\Chordata\
\Chordata\
\Lophotrochozoa\
\Chordata\
\Dikarya\
\Chordata\
\Chordata\
\Chordata\
\Lophotrochozoa\
\Streptophyta\
\Chordata\
\Chordata\
\Streptophyta\
\Dikarya\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Chordata\
\Streptophyta\
\Streptophyta\
\Streptophyta\
\Streptophyta\

# %%
#This returns 854 blanks. It skips the rows with content.
Why doesn't it print the content in the row when the lag has content?

SELECT lag ( order_03, 1, NULL) OVER (ORDER BY food_id)
FROM food_taxonomies
WHERE order_03 IS NULL

# %% [markdown]
# [(Back to top)](#top)
# # Exploratory data analysis

# %% [markdown]
# <a id = 'eda_compounds'></a>

# %% [markdown]
# ## compounds table

# %%
compounds = pd.read_sql_query('''SELECT c.* 
                            FROM compounds c
                            ;''', engine)
# Out:
# 2019-03-16 11:06:04,975 INFO sqlalchemy.engine.base.Engine SELECT c.*
#                             FROM compounds c
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT c.*
#                             FROM compounds c
#                             ;
# 2019-03-16 11:06:04,975 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28771 entries, 0 to 28770
# Columns: 106 entries, id to phytohub_id
# dtypes: object(106)
# memory usage: 23.3+ MB

# %%
for column in compounds.columns:
    print(column, compounds[compounds[column] != ''].shape[0])
# Out:
# id 28771
# legacy_id 19331
# type 28771
# public_id 28771
# name 28771
# export 28771
# state 9169
# annotation_quality 27471
# description 23292
# cas_number 18213
# melting_point 6926
# protein_formula 0
# protein_weight 0
# experimental_solubility 886
# experimental_logp 890
# hydrophobicity 0
# isoelectric_point 0
# metabolism 1
# kegg_compound_id 6651
# pubchem_compound_id 17854
# pubchem_substance_id 5
# chebi_id 2530
# het_id 974
# uniprot_id 0
# uniprot_name 0
# genbank_id 0
# wikipedia_id 4502
# synthesis_citations 0
# general_citations 171
# comments 476
# protein_structure_file_name 0
# protein_structure_content_type 0
# protein_structure_file_size 0
# protein_structure_updated_at 0
# msds_file_name 1453
# msds_content_type 1453
# msds_file_size 1453
# msds_updated_at 1453
# creator_id 76
# updater_id 6568
# created_at 28771
# updated_at 28771
# phenolexplorer_id 777
# dfc_id 15059
# hmdb_id 20760
# duke_id 6193
# drugbank_id 693
# bigg_id 876
# eafus_id 2950
# knapsack_id 4814
# boiling_point 2304
# boiling_point_reference 2217
# charge 64
# charge_reference 0
# density 773
# density_reference 773
# optical_rotation 5151
# optical_rotation_reference 5151
# percent_composition 14043
# percent_composition_reference 14043
# physical_description 125
# physical_description_reference 125
# refractive_index 858
# refractive_index_reference 858
# uv_index 2067
# uv_index_reference 2067
# experimental_pka 532
# experimental_pka_reference 342
# experimental_solubility_reference 852
# experimental_logp_reference 864
# hydrophobicity_reference 0
# isoelectric_point_reference 0
# melting_point_reference 6273
# moldb_alogps_logp 23531
# moldb_logp 24401
# moldb_alogps_logs 23531
# moldb_smiles 26490
# moldb_pka 13033
# moldb_formula 26494
# moldb_average_mass 26494
# moldb_inchi 26495
# moldb_mono_mass 26494
# moldb_inchikey 26495
# moldb_alogps_solubility 23531
# moldb_id 24399
# moldb_iupac 24397
# structure_source 24460
# duplicate_id 87
# old_dfc_id 219
# dfc_name 14776
# compound_source 28771
# flavornet_id 731
# goodscent_id 2598
# superscent_id 417
# phenolexplorer_metabolite_id 372
# kingdom 5265
# superklass 5265
# klass 5225
# subklass 4666
# direct_parent 5265
# molecular_framework 5259
# chembl_id 2820
# chemspider_id 14763
# meta_cyc_id 4621
# foodcomex 1045
# phytohub_id 0

# %%
compound_columns_to_drop = []

# %%
for column in compounds.columns:
    if compounds[compounds[column] != ''].shape[0] < 23000:
        compound_columns_to_drop.append(column)

# %%
len(compound_columns_to_drop)
# Out:
# 83

# %% [markdown]
# ### Dropped almost all columns

# %% [markdown]
# # Exploratory data analysis
# ## compounds enzymes table

# %%
compounds_enzymes = pd.read_sql_query('''SELECT ce.* 
                            FROM compounds_enzymes ce
                            ;''', engine)
# Out:
# 2019-03-16 12:58:57,770 INFO sqlalchemy.engine.base.Engine SELECT ce.*
#                             FROM compounds_enzymes ce
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT ce.*
#                             FROM compounds_enzymes ce
#                             ;
# 2019-03-16 12:58:57,772 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds_enzymes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105089 entries, 0 to 105088
# Data columns (total 3 columns):
# id             105089 non-null int64
# compound_id    105089 non-null int64
# enzyme_id      105089 non-null int64
# dtypes: int64(3)
# memory usage: 2.4 MB

# %%
compounds_enzymes.head()
# Out:
#   id compound_id enzyme_id citations           created_at  \
# 0  1         362         1      HMDB  2015-02-23 22:40:56
# 1  2         362         2      HMDB  2015-02-23 22:40:57
# 2  3         362         3      HMDB  2015-02-23 22:40:57
# 3  4         362         4      HMDB  2015-02-23 22:40:57
# 4  5         362         5      HMDB  2015-02-23 22:40:57
#
#             updated_at creator_id updater_id
# 0  2015-02-23 22:40:56       NULL       NULL
# 1  2015-02-23 22:40:57       NULL       NULL
# 2  2015-02-23 22:40:57       NULL       NULL
# 3  2015-02-23 22:40:57       NULL       NULL
# 4  2015-02-23 22:40:57       NULL       NULL

# %% [markdown]
# ### A given compound id may correspond to many enzyme_ids. This seems okay. The enzymes table has the names of all the enzymes corresponding to these ids. Need to set foreign key for enzyme_id.
#
# ### To drop: everything except id INTEGER PRIMARY KEY, compound_id INTEGER, enzyme id INTEGER FOREIGN KEY.

# %% [markdown]
# # Exploratory data analysis
# ## compounds flavors table

# %%
compounds_flavors = pd.read_sql_query('''SELECT cf.* 
                            FROM compounds_flavors cf
                            ;''', engine)
# Out:
# 2019-03-16 12:58:22,986 INFO sqlalchemy.engine.base.Engine SELECT cf.*
#                             FROM compounds_flavors cf
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT cf.*
#                             FROM compounds_flavors cf
#                             ;
# 2019-03-16 12:58:22,996 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds_flavors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11613 entries, 0 to 11612
# Data columns (total 10 columns):
# id             11613 non-null object
# compound_id    11613 non-null object
# flavor_id      11613 non-null object
# citations      11613 non-null object
# created_at     11613 non-null object
# updated_at     11613 non-null object
# creator_id     11613 non-null object
# updater_id     11613 non-null object
# source_id      11613 non-null object
# source_type    11613 non-null object
# dtypes: object(10)
# memory usage: 907.3+ KB

# %%
compounds_flavors.head(3)
# Out:
#   id compound_id flavor_id                                          citations  \
# 0  1       11947       159  # Arn, H, Acree TE. ���Flavornet: A database o...
# 1  2        8298       213  # Arn, H, Acree TE. ���Flavornet: A database o...
# 2  3        8298       156  # Arn, H, Acree TE. ���Flavornet: A database o...
#
#                 created_at               updated_at creator_id updater_id  \
# 0  2011-10-02 06:30:05 UTC  2015-10-23 23:29:45 UTC
# 1  2011-10-02 06:30:05 UTC  2015-10-23 23:29:56 UTC
# 2  2011-10-02 06:30:05 UTC  2015-10-23 23:29:45 UTC
#
#   source_id source_type
# 0     11947    Compound
# 1      8298    Compound
# 2      8298    Compound

# %%
#test query to see how it will look to bring together compounds and flavors
pd.read_sql_query('''SELECT fl.name
                        FROM compounds_flavors cf
                        JOIN flavors fl ON fl.id = cf.flavor_id
                        WHERE cf.compound_id == '11947'
                    ;''', engine)
# Out:
# 2019-03-16 13:14:17,294 INFO sqlalchemy.engine.base.Engine SELECT fl.name
#                         FROM compounds_flavors cf
#                         JOIN flavors fl ON fl.id = cf.flavor_id
#                         WHERE cf.compound_id == '11947'
#                     ;
# INFO:sqlalchemy.engine.base.Engine:SELECT fl.name
#                         FROM compounds_flavors cf
#                         JOIN flavors fl ON fl.id = cf.flavor_id
#                         WHERE cf.compound_id == '11947'
#                     ;
# 2019-03-16 13:14:17,294 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#      name
# 0    fish
# 1   fishy
# 2    oily
# 3  rancid
# 4  sweaty
# 5  fruity

# %% [markdown]
# ### 2816 compound_ids, 716 flavor ids.
#
# ### Only keep compound_id FOREIGN KEY, flavor_id FOREIGN KEy.

# %% [markdown]
# # Exploratory data analysis
# ## compounds health effects table

# %%
compounds_health_effects = pd.read_sql_query('''SELECT che.* 
                            FROM compounds_health_effects che
                            ;''', engine)
# Out:
# 2019-03-16 13:25:55,526 INFO sqlalchemy.engine.base.Engine SELECT che.*
#                             FROM compounds_health_effects che
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT che.*
#                             FROM compounds_health_effects che
#                             ;
# 2019-03-16 13:25:55,526 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds_health_effects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11091 entries, 0 to 11090
# Data columns (total 14 columns):
# id                         11091 non-null object
# compound_id                11091 non-null object
# health_effect_id           11091 non-null object
# orig_health_effect_name    11091 non-null object
# orig_compound_name         11091 non-null object
# orig_citation              11091 non-null object
# citation                   11091 non-null object
# citation_type              11091 non-null object
# created_at                 11091 non-null object
# updated_at                 11091 non-null object
# creator_id                 11091 non-null object
# updater_id                 11091 non-null object
# source_id                  11091 non-null object
# source_type                11091 non-null object
# dtypes: object(14)
# memory usage: 1.2+ MB

# %%
compounds_health_effects.head()
# Out:
#   id compound_id health_effect_id orig_health_effect_name orig_compound_name  \
# 0  1         453                1           (+)-Inotropic       THEOPHYLLINE
# 1  2        2100                1           (+)-Inotropic           CAFFEINE
# 2  3        9030                2        (-)-Chronotropic     BORNYL-ACETATE
# 3  4       13577                2        (-)-Chronotropic            BORNEOL
# 4  5       14619                2        (-)-Chronotropic        1,8-CINEOLE
#
#   orig_citation citation citation_type     created_at     updated_at  \
# 0          NULL     DUKE      DATABASE  4/10/12 14:16  11/5/14 14:49
# 1          NULL     DUKE      DATABASE  4/10/12 14:16  11/5/14 14:49
# 2          NULL     DUKE      DATABASE  4/10/12 14:16  11/5/14 14:49
# 3          NULL     DUKE      DATABASE  4/10/12 14:16  11/5/14 14:49
# 4          NULL     DUKE      DATABASE  4/10/12 14:16  11/5/14 14:49
#
#   creator_id updater_id source_id source_type
# 0       NULL       NULL       453    Compound
# 1       NULL       NULL      2100    Compound
# 2       NULL       NULL      9030    Compound
# 3       NULL       NULL     13577    Compound
# 4       NULL       NULL     14619    Compound

# %%
compounds[compounds['id'] == 14619]
# Out:
#           id         name                                        description  \
# 12177  14619  1,8-Cineole  Occurs in eucalyptus, lavender, sage and many ...
#
#       moldb_formula moldb_id
# 12177       C10H18O    35937

# %%
health_effects.head()
# Out:
#    id                                           name  \
# 0   1                                  (+)-inotropic
# 1   2                               (-)-chronotropic
# 2   3                                  (-)-inotropic
# 3   4  11beta-hydroxysteroid-dehydrogenase inhibitor
# 4   5                      12-lipoxygenase inhibitor
#
#                                          description        chebi_name  \
# 0  An agent that alters the force or energy of mu...              NULL
# 1  An agent that may change theÂ heartÂ rate by a...              NULL
# 2  An agent that alters the force or energy of mu...              NULL
# 3                                               NULL  enzyme inhibitor
# 4                                               NULL  enzyme inhibitor
#
#   chebi_id                                   chebi_definition
# 0     NULL                                               NULL
# 1     NULL                                               NULL
# 2     NULL                                               NULL
# 3    23924  A compound or agent that combines with an enzy...
# 4    23924  A compound or agent that combines with an enzy...

# %% [markdown]
# ### Only need to keep compound_id and health_effect_id. Brief comparison with compound table and health effect table shows that this table's "original health effect name" and "original compound name" columns aren't necessary. This info is contained in the health effects and compound tables.

# %% [markdown]
# # Exploratory data analysis
# ## compounds pathways table

# %%
compounds_pathways = pd.read_sql_query('''SELECT cp.* 
                            FROM compounds_pathways cp
                            ;''', engine)
# Out:
# 2019-03-16 13:39:26,276 INFO sqlalchemy.engine.base.Engine SELECT cp.*
#                             FROM compounds_pathways cp
#                             ;
# INFO:sqlalchemy.engine.base.Engine:SELECT cp.*
#                             FROM compounds_pathways cp
#                             ;
# 2019-03-16 13:39:26,276 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds_pathways.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1604 entries, 0 to 1603
# Data columns (total 7 columns):
# id             1604 non-null object
# compound_id    1604 non-null object
# pathway_id     1604 non-null object
# creator_id     1604 non-null object
# updater_id     1604 non-null object
# created_at     1604 non-null object
# updated_at     1604 non-null object
# dtypes: object(7)
# memory usage: 87.8+ KB

# %%
compounds_pathways.head()
# Out:
#   id compound_id pathway_id creator_id updater_id           created_at  \
# 0  1         316          1       NULL       NULL  2015-02-23 22:40:48
# 1  2         362          2       NULL       NULL  2015-02-23 22:40:58
# 2  3         374          3       NULL       NULL  2015-02-23 22:41:14
# 3  4         374          4       NULL       NULL  2015-02-23 22:41:14
# 4  5         433          1       NULL       NULL  2015-02-23 22:42:20
#
#             updated_at
# 0  2015-02-23 22:40:48
# 1  2015-02-23 22:40:58
# 2  2015-02-23 22:41:14
# 3  2015-02-23 22:41:14
# 4  2015-02-23 22:42:20

# %% [markdown]
# ### Only keep compound_id and pathway_id.

# %% [markdown]
# <a id = 'droppingcolumns'></a>

# %% [markdown]
# [(Back to top)](#top)
#
# # Dropping columns

# %% [markdown]
# <a id = 'dropcol_foods'></a>

# %% [markdown]
# ## Dropping columns from food table

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
#Look at columns in foods table
cur.execute('''PRAGMA table_info(foods)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'name', '', 0, None, 0),
#  (2, 'name_scientific', '', 0, None, 0),
#  (3, 'description', '', 0, None, 0),
#  (4, 'itis_id', '', 0, None, 0),
#  (5, 'wikipedia_id', '', 0, None, 0),
#  (6, 'wikipedia_id_img', '', 0, None, 0),
#  (7, 'picture_content_type', '', 0, None, 0),
#  (8, 'picture_file_size', '', 0, None, 0),
#  (9, 'picture_updated_at', '', 0, None, 0),
#  (10, 'legacy_id', '', 0, None, 0),
#  (11, 'food_group', '', 0, None, 0),
#  (12, 'food_subgroup', '', 0, None, 0),
#  (13, 'food_type', '', 0, None, 0),
#  (14, 'created_at', '', 0, None, 0),
#  (15, 'updated_at', '', 0, None, 0),
#  (16, 'creator_id', '', 0, None, 0),
#  (17, 'updater_id', '', 0, None, 0),
#  (18, 'export_to_afcdb', '', 0, None, 0),
#  (19, 'category', '', 0, None, 0),
#  (20, 'ncbi_taxonomy_id', '', 0, None, 0),
#  (21, 'export_to_foodb', '', 0, None, 0)]

# %%
#Create a new foods table
cur.execute('''CREATE TABLE foods_copy
                (id INTEGER PRIMARY KEY, name TEXT, name_scientific TEXT, 
                description TEXT, wikipedia_id TEXT, wikipedia_id_img TEXT,
                food_group TEXT, food_subgroup TEXT, food_type TEXT, 
                category TEXT, ncbi_taxonomy_id INTEGER)
            ;''')

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO foods_copy
                    (id, name, name_scientific, 
                    description, wikipedia_id, wikipedia_id_img,
                    food_group, food_subgroup, food_type, 
                    category, ncbi_taxonomy_id)
                SELECT id, name, name_scientific, 
                    description, wikipedia_id, wikipedia_id_img, 
                    food_group, food_subgroup, food_type, 
                    category, ncbi_taxonomy_id
                FROM foods
            ;''')

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM foods_copy
                LIMIT 5
            ;''').fetchall()

#Check that columns were populated from old table
#Doesn't work before commit. Works after commit.
#pd.read_sql_query('''SELECT * 
#                        FROM foods_copy
#                    ;''', engine)
# Out:
# [(1,
#   'Angelica',
#   'Angelica keiskei',
#   'Angelica is a genus of about 60 species of tall biennial and perennial herbs in the family Apiaceae, native to temperate and subarctic regions of the Northern Hemisphere, reaching as far north as Iceland and Lapland. They grow to 1äóñ3 m tall, with large bipinnate leaves and large compound umbels of white or greenish-white flowers. Some species can be found in purple moor and rush pastures.',
#   'Angelica',
#   '1.jpg',
#   'Herbs and Spices',
#   'Herbs',
#   'Type 1',
#   'specific',
#   357850),
#  (2,
#   'Savoy cabbage',
#   'Brassica oleracea var. sabauda',
#   'Savoy cabbage (Brassica oleracea convar. capitata var. sabauda L. ) is a variety of the cabbage, a cultivar of the plant species Brassica oleracea. Savoy cabbage is a winter vegetable. A variety of the savoy cabbage is the January King Cabbage. Savoy cabbage can be used in a variety of recipes. It pairs well with red wine, apples, spices, horseradish and meat. It can be used for roulades, in stews and soups, as well as roasted plain and drizzled with olive oil. Cabbage that is heavy for its size with leaves that are unblemished and have a bright, fresh look are signs of desirable quality. Whole cabbages are preferred whenever possible as pre-cut or preshredded cabbage has a greatly diminished vitamin content. Peak season for most cabbages runs from November through April. Fresh whole cabbage will keep in the refrigerator for one to six weeks depending on type and variety. Hard green, white or red cabbages will keep the longest while the looser Savoy and Chinese varieties need to be consumed more quickly. It is necessary to keep the outer leaves intact without washing when storing since moisture hastens decay. Cabbage provides fiber, vitamins A, C, K and B6, folate, potassium, manganese, thiamin, calcium, iron and magnesium.',
#   'Savoy cabbage',
#   '2.jpg',
#   'Vegetables',
#   'Cabbages',
#   'Type 1',
#   'specific',
#   1216010),
#  (3,
#   'Silver linden',
#   'Tilia argentea',
#   'Tilia tomentosa (Silver Lime in the UK and Silver Linden in the US) is a species of Tilia native to southeastern Europe and southwestern Asia, from Hungary and the Balkans east to western Turkey, occurring at moderate altitudes. It is a deciduous tree growing to 20äóñ35 m tall, with a trunk up to 2 m diameter. The leaves are alternately arranged, rounded to triangular-ovate, 4äóñ13\x8cæcm long and broad with a 2.5äóñ4\x8cæcm petiole, green and mostly hairless above, densely white tomentose with white hairs below, and with a coarsely toothed margin. The flowers are pale yellow, hermaphrodite, produced in cymes of three to ten in mid to late summer with a pale green subtending leafy bract; they have a strong scent and are pollinated by honeybees. The nectar however contains sugars which cannot be digested by other bees, to whom the tree is somewhat toxic. The fruit is a dry nut-like drupe 8äóñ10\x8cæmm long, downy, and slightly ribbed.',
#   'Tilia tomentosa',
#   '3.jpg',
#   'Herbs and Spices',
#   'Herbs',
#   'Type 1',
#   'specific',
#   ''),
#  (4,
#   'Kiwi',
#   'Actinidia chinensis',
#   "The kiwifruit, often shortened to kiwi in many parts of the world, is the edible berry of a woody vine in the genus Actinidia. The most common cultivar group of kiwifruit ('Hayward') is oval, about the size of a large hen's egg (5?8 centimetres in length and 4.5?5.5 centimetres in diameter). It has a fibrous, dull greenish-brown skin and bright green or golden flesh with rows of tiny, black, edible seeds. The fruit has a soft texture and a sweet but unique flavor, and today is a commercial crop in several countries, such as Italy, New Zealand, Chile, Greece and France.",
#   'Kiwifruit',
#   '4.jpg',
#   'Fruits',
#   'Tropical fruits',
#   'Type 1',
#   'specific',
#   3625),
#  (5,
#   'Allium (Onion)',
#   'Allium',
#   'Allium haematochiton is a species of wild onion known by the common name redskin onion. It is native to northern Baja California and southern California. It it grows on the slopes of the coastal hills and mountains, such as those of the Peninsular Ranges, Transverse Ranges, and southern California Coast Ranges.',
#   'Allium haematochiton',
#   '5.jpg',
#   'Vegetables',
#   'Onion-family vegetables',
#   'Type 1',
#   'specific',
#   4678)]

# %%
foods_copy_Nones = foods_copy['ncbi_taxonomy_id'] == ''

# %%
foods_copy_Nones.value_counts()
# Out:
# False    631
# True     276
# Name: ncbi_taxonomy_id, dtype: int64

# %% [markdown]
# Null values are not reading as Null but there are empty values.

# %%
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(foods_copy)
;''',).fetchall()

#Check data types of new table
#Only works after commit
#New table dropped 90kb from memory compared to old table
#foods_copy = pd.read_sql_query('''SELECT * 
#                        FROM foods_copy
#                    ;''', engine)
#foods_copy.info()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'name_scientific', 'TEXT', 0, None, 0),
#  (3, 'description', 'TEXT', 0, None, 0),
#  (4, 'wikipedia_id', 'TEXT', 0, None, 0),
#  (5, 'wikipedia_id_img', 'TEXT', 0, None, 0),
#  (6, 'food_group', 'TEXT', 0, None, 0),
#  (7, 'food_subgroup', 'TEXT', 0, None, 0),
#  (8, 'food_type', 'TEXT', 0, None, 0),
#  (9, 'category', 'TEXT', 0, None, 0),
#  (10, 'ncbi_taxonomy_id', 'INTEGER', 0, None, 0)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(foods_copy)
;''',).fetchall()

# %%
#Delete the old table
cur.execute('''DROP TABLE foods;''')

# %%
#Rename new table to  foods
cur.execute('''ALTER TABLE foods_copy
                RENAME TO foods
                ;''')

# %%
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compound_alternate_parents',),
#  ('compound_external_descriptors',),
#  ('compound_substituents',),
#  ('compound_synonyms',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('compounds',),
#  ('enzymes',),
#  ('flavors',),
#  ('food_taxonomies',),
#  ('foodcomex_compound_providers',),
#  ('foodcomex_compounds',),
#  ('health_effects',),
#  ('nutrients',),
#  ('pathways',),
#  ('references',),
#  ('foods',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(foods)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'name_scientific', 'TEXT', 0, None, 0),
#  (3, 'description', 'TEXT', 0, None, 0),
#  (4, 'wikipedia_id', 'TEXT', 0, None, 0),
#  (5, 'wikipedia_id_img', 'TEXT', 0, None, 0),
#  (6, 'food_group', 'TEXT', 0, None, 0),
#  (7, 'food_subgroup', 'TEXT', 0, None, 0),
#  (8, 'food_type', 'TEXT', 0, None, 0),
#  (9, 'category', 'TEXT', 0, None, 0),
#  (10, 'ncbi_taxonomy_id', 'INTEGER', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %%
# We can also close the connection if we are done with it.
# Just be sure any changes have been committed or they will be lost.
connection.close()

# %% [markdown]
# [(Back to top)](#top)

# %% [markdown]
# <a id = 'dropcol_enzymes'></a>

# %% [markdown]
# ## Dropping columns from enzymes table

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(enzymes)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'name', '', 0, None, 0),
#  (2, 'gene_name', '', 0, None, 0),
#  (3, 'description', '', 0, None, 0),
#  (4, 'go_classification', '', 0, None, 0),
#  (5, 'general_function', '', 0, None, 0),
#  (6, 'specific_function', '', 0, None, 0),
#  (7, 'pathway', '', 0, None, 0),
#  (8, 'reaction', '', 0, None, 0),
#  (9, 'cellular_location', '', 0, None, 0),
#  (10, 'signals', '', 0, None, 0),
#  (11, 'transmembrane_regions', '', 0, None, 0),
#  (12, 'molecular_weight', '', 0, None, 0),
#  (13, 'theoretical_pi', '', 0, None, 0),
#  (14, 'locus', '', 0, None, 0),
#  (15, 'chromosome', '', 0, None, 0),
#  (16, 'uniprot_name', '', 0, None, 0),
#  (17, 'uniprot_id', '', 0, None, 0),
#  (18, 'pdb_id', '', 0, None, 0),
#  (19, 'genbank_protein_id', '', 0, None, 0),
#  (20, 'genbank_gene_id', '', 0, None, 0),
#  (21, 'genecard_id', '', 0, None, 0),
#  (22, 'genatlas_id', '', 0, None, 0),
#  (23, 'hgnc_id', '', 0, None, 0),
#  (24, 'hprd_id', '', 0, None, 0),
#  (25, 'organism', '', 0, None, 0),
#  (26, 'general_citations', '', 0, None, 0),
#  (27, 'comments', '', 0, None, 0),
#  (28, 'creator_id', '', 0, None, 0),
#  (29, 'updater_id', '', 0, None, 0),
#  (30, 'created_at', '', 0, None, 0),
#  (31, 'updated_at', '', 0, None, 0)]

# %%
#Create a new enzymes table
cur.execute('''CREATE TABLE enzymes_copy
                (id INTEGER PRIMARY KEY, name TEXT, gene_name TEXT, 
                uniprot_id TEXT)
            ;''')

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(enzymes_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'gene_name', 'TEXT', 0, None, 0),
#  (3, 'uniprot_id', 'TEXT', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO enzymes_copy
                    (id, name, gene_name, uniprot_id)
                SELECT id, name, gene_name, uniprot_id
                FROM enzymes
            ;''')

# %%
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(enzymes_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'gene_name', 'TEXT', 0, None, 0),
#  (3, 'uniprot_id', 'TEXT', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM enzymes_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(1, 'UDP-glucuronosyltransferase 2B28', 'UGT2B28', 'Q9BY64'),
#  (2, 'Estrogen receptor beta', 'ESR2', 'Q92731'),
#  (3, 'UDP-glucuronosyltransferase 2B4', 'UGT2B4', 'P06133'),
#  (4, 'UDP-glucuronosyltransferase 1-4', 'UGT1A4', 'P22310'),
#  (5, 'UDP-glucuronosyltransferase 2B10', 'UGT2B10', 'P36537')]

# %%
#Delete the old table
cur.execute('''DROP TABLE enzymes;''')

# %%
#Rename new table to enzymes
cur.execute('''ALTER TABLE enzymes_copy
                RENAME TO enzymes
                ;''')

# %%
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compound_alternate_parents',),
#  ('compound_external_descriptors',),
#  ('compound_substituents',),
#  ('compound_synonyms',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('compounds',),
#  ('flavors',),
#  ('food_taxonomies',),
#  ('foodcomex_compound_providers',),
#  ('foodcomex_compounds',),
#  ('health_effects',),
#  ('nutrients',),
#  ('pathways',),
#  ('references',),
#  ('foods',),
#  ('enzymes',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(enzymes)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'gene_name', 'TEXT', 0, None, 0),
#  (3, 'uniprot_id', 'TEXT', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)

# %% [markdown]
# <a id = 'dropcol_health_effects'></a>

# %% [markdown]
# ## Dropping columns from health_effects table

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(health_effects)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'name', '', 0, None, 0),
#  (2, 'description', '', 0, None, 0),
#  (3, 'chebi_name', '', 0, None, 0),
#  (4, 'chebi_id', '', 0, None, 0),
#  (5, 'created_at', '', 0, None, 0),
#  (6, 'updated_at', '', 0, None, 0),
#  (7, 'creator_id', '', 0, None, 0),
#  (8, 'updater_id', '', 0, None, 0),
#  (9, 'chebi_definition', '', 0, None, 0)]

# %%
#Create a new enzymes table
cur.execute('''CREATE TABLE health_effects_copy
                (id INTEGER PRIMARY KEY, name TEXT, description TEXT, 
                chebi_name TEXT, chebi_id INTEGER, chebi_definition TEXT)
            ;''')

#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(health_effects_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'description', 'TEXT', 0, None, 0),
#  (3, 'chebi_name', 'TEXT', 0, None, 0),
#  (4, 'chebi_id', 'INTEGER', 0, None, 0),
#  (5, 'chebi_definition', 'TEXT', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO health_effects_copy
                    (id, name, description,
                    chebi_name, chebi_id, chebi_definition)
                SELECT id, name, description,
                    chebi_name, chebi_id, chebi_definition
                FROM health_effects
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(health_effects_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'description', 'TEXT', 0, None, 0),
#  (3, 'chebi_name', 'TEXT', 0, None, 0),
#  (4, 'chebi_id', 'INTEGER', 0, None, 0),
#  (5, 'chebi_definition', 'TEXT', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM health_effects_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(1,
#   '(+)-inotropic',
#   'An agent that alters the force or energy of muscular contractions. Positively inotropic agents increase the strength of muscular contraction.',
#   'NULL',
#   'NULL',
#   'NULL'),
#  (2,
#   '(-)-chronotropic',
#   'An agent that may change theÂ\xa0heartÂ\xa0rate by affecting theÂ\xa0nervesÂ\xa0controlling the heart, or by changing theÂ\xa0rhythmÂ\xa0produced by theÂ\xa0sinoatrial node. Negative chronotropes decrease heart rate.',
#   'NULL',
#   'NULL',
#   'NULL'),
#  (3,
#   '(-)-inotropic',
#   'An agent that alters the force or energy of muscular contractions. NegativelyÂ\xa0inotropicÂ\xa0agents weaken the force of muscular contractions.',
#   'NULL',
#   'NULL',
#   'NULL'),
#  (4,
#   '11beta-hydroxysteroid-dehydrogenase inhibitor',
#   'NULL',
#   'enzyme inhibitor',
#   23924,
#   'A compound or agent that combines with an enzyme in such a manner as to prevent the normal substrate-enzyme combination and the catalytic reaction.'),
#  (5,
#   '12-lipoxygenase inhibitor',
#   'NULL',
#   'enzyme inhibitor',
#   23924,
#   'A compound or agent that combines with an enzyme in such a manner as to prevent the normal substrate-enzyme combination and the catalytic reaction.')]

# %%
#Delete the old table
cur.execute('''DROP TABLE health_effects;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE health_effects_copy
                RENAME TO health_effects
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compound_alternate_parents',),
#  ('compound_external_descriptors',),
#  ('compound_substituents',),
#  ('compound_synonyms',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('compounds',),
#  ('flavors',),
#  ('food_taxonomies',),
#  ('foodcomex_compound_providers',),
#  ('foodcomex_compounds',),
#  ('nutrients',),
#  ('pathways',),
#  ('references',),
#  ('foods',),
#  ('enzymes',),
#  ('health_effects',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(health_effects)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'description', 'TEXT', 0, None, 0),
#  (3, 'chebi_name', 'TEXT', 0, None, 0),
#  (4, 'chebi_id', 'INTEGER', 0, None, 0),
#  (5, 'chebi_definition', 'TEXT', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)

# %% [markdown]
# <a id = 'dropcol_flavors'></a>

# %% [markdown]
# ## Dropping columns from flavors table

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(flavors)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'name', '', 0, None, 0),
#  (2, 'flavor_group', '', 0, None, 0),
#  (3, 'category', '', 0, None, 0),
#  (4, 'created_at', '', 0, None, 0),
#  (5, 'updated_at', '', 0, None, 0),
#  (6, 'creator_id', '', 0, None, 0),
#  (7, 'updater_id', '', 0, None, 0)]

# %%
#Create a new enzymes table
cur.execute('''CREATE TABLE flavors_copy
                (id INTEGER PRIMARY KEY, name TEXT, flavor_group TEXT)
            ;''')

#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(flavors_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'flavor_group', 'TEXT', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO flavors_copy
                    (id, name, flavor_group)
                SELECT id, name, flavor_group
                FROM flavors
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(flavors_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'flavor_group', 'TEXT', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM flavors_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(1, 'celery', 'vegetable'),
#  (2, 'corn', 'vegetable'),
#  (3, 'cucumber', 'vegetable'),
#  (4, 'horseradish', 'vegetable'),
#  (5, 'vegetable', 'vegetable')]

# %%
#Delete the old table
cur.execute('''DROP TABLE flavors;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE flavors_copy
                RENAME TO flavors
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compound_alternate_parents',),
#  ('compound_external_descriptors',),
#  ('compound_substituents',),
#  ('compound_synonyms',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('compounds',),
#  ('food_taxonomies',),
#  ('foodcomex_compound_providers',),
#  ('foodcomex_compounds',),
#  ('nutrients',),
#  ('pathways',),
#  ('references',),
#  ('foods',),
#  ('enzymes',),
#  ('health_effects',),
#  ('flavors',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(flavors)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'flavor_group', 'TEXT', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)

# %% [markdown]
# <a id = 'dropcol_pathways'></a>

# %% [markdown]
# ## Dropping columns from pathways table

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(pathways)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'smpdb_id', '', 0, None, 0),
#  (2, 'kegg_map_id', '', 0, None, 0),
#  (3, 'name', '', 0, None, 0),
#  (4, 'created_at', '', 0, None, 0),
#  (5, 'updated_at', '', 0, None, 0)]

# %%
#Create a new  table
cur.execute('''CREATE TABLE pathways_copy
                (id INTEGER PRIMARY KEY, smpdb_id TEXT, kegg_map_id TEXT, 
                name TEXT)
            ;''')

#Insert values into columns of new table
cur.execute('''INSERT INTO pathways_copy
                    (id, smpdb_id, kegg_map_id, name)
                SELECT id, smpdb_id, kegg_map_id, name
                FROM pathways
            ;''')

#Delete the old table
cur.execute('''DROP TABLE pathways;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE pathways_copy
                RENAME TO pathways
                ;''')

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(pathways)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'smpdb_id', 'TEXT', 0, None, 0),
#  (2, 'kegg_map_id', 'TEXT', 0, None, 0),
#  (3, 'name', 'TEXT', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM pathways
                LIMIT 3
            ;''').fetchall()
# Out:
# [(1, 'SMP00006', 'map00350', 'Tyrosine Metabolism'),
#  (2, 'SMP00068', 'map00150', 'Androgen and Estrogen Metabolism'),
#  (3, 'SMP00011', 'map00562', 'Inositol Metabolism')]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)

# %% [markdown]
# <a id = 'dropcol_food_tax'></a>

# %% [markdown]
# ## Dropping columns from food_taxonomies table

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(food_taxonomies)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 0),
#  (1, 'food_id', 'INTEGER', 0, None, 0),
#  (2, 'ncbi_taxonomy_id', 'INTEGER', 0, None, 0),
#  (3, 'classification_name', 'TEXT', 0, None, 0),
#  (4, 'classification_order', 'INTEGER', 0, None, 0),
#  (5, 'order_18', 'INTEGER', 0, None, 0),
#  (6, 'order_17', 'INTEGER', 0, None, 0),
#  (7, 'order_16', 'INTEGER', 0, None, 0),
#  (8, 'order_15', 'INTEGER', 0, None, 0),
#  (9, 'order_14', 'INTEGER', 0, None, 0),
#  (10, 'order_13', 'INTEGER', 0, None, 0),
#  (11, 'order_12', 'INTEGER', 0, None, 0),
#  (12, 'order_11', 'INTEGER', 0, None, 0),
#  (13, 'order_10', 'INTEGER', 0, None, 0),
#  (14, 'order_09', 'INTEGER', 0, None, 0),
#  (15, 'order_08', 'INTEGER', 0, None, 0),
#  (16, 'order_07', 'INTEGER', 0, None, 0),
#  (17, 'order_06', 'INTEGER', 0, None, 0),
#  (18, 'order_05', 'INTEGER', 0, None, 0),
#  (19, 'order_04', 'INTEGER', 0, None, 0),
#  (20, 'order_03', 'INTEGER', 0, None, 0),
#  (21, 'order_02', 'INTEGER', 0, None, 0),
#  (22, 'order_01', 'INTEGER', 0, None, 0)]

# %%
#Create a new  table
cur.execute('''CREATE TABLE food_taxonomies_copy
                (id INTEGER PRIMARY KEY, food_id INTEGER, 
                ncbi_taxonomy_id INTEGER, classification_name TEXT, 
                classification_order INTEGER,
                order_18 TEXT,
                order_17 TEXT, order_16 TEXT, order_15 TEXT, order_14 TEXT, order_13 TEXT,
                order_12 TEXT, order_11 TEXT, order_10 TEXT, order_09 TEXT, order_08 TEXT,
                order_07 TEXT, order_06 TEXT, order_05 TEXT, order_04 TEXT, order_03 TEXT,
                order_02 TEXT, order_01 TEXT,
                FOREIGN KEY(food_id) REFERENCES foods(id))
            ;''')

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO food_taxonomies_copy
                    (id, food_id, ncbi_taxonomy_id, classification_name,
                    classification_order,
                order_18, order_17, order_16, order_15, order_14, order_13,
                order_12, order_11, order_10, order_09, order_08,
                order_07, order_06, order_05, order_04, order_03,
                order_02, order_01)
                SELECT id, food_id, ncbi_taxonomy_id, classification_name,
                    classification_order, 
                order_18, order_17, order_16, order_15, order_14, order_13,
                order_12, order_11, order_10, order_09, order_08,
                order_07, order_06, order_05, order_04, order_03,
                order_02, order_01
                FROM food_taxonomies
            ;''')

#Delete the old table
cur.execute('''DROP TABLE food_taxonomies;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE food_taxonomies_copy
                RENAME TO food_taxonomies
                ;''')

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(food_taxonomies)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'food_id', 'INTEGER', 0, None, 0),
#  (2, 'ncbi_taxonomy_id', 'INTEGER', 0, None, 0),
#  (3, 'classification_name', 'TEXT', 0, None, 0),
#  (4, 'classification_order', 'INTEGER', 0, None, 0),
#  (5, 'order_18', 'TEXT', 0, None, 0),
#  (6, 'order_17', 'TEXT', 0, None, 0),
#  (7, 'order_16', 'TEXT', 0, None, 0),
#  (8, 'order_15', 'TEXT', 0, None, 0),
#  (9, 'order_14', 'TEXT', 0, None, 0),
#  (10, 'order_13', 'TEXT', 0, None, 0),
#  (11, 'order_12', 'TEXT', 0, None, 0),
#  (12, 'order_11', 'TEXT', 0, None, 0),
#  (13, 'order_10', 'TEXT', 0, None, 0),
#  (14, 'order_09', 'TEXT', 0, None, 0),
#  (15, 'order_08', 'TEXT', 0, None, 0),
#  (16, 'order_07', 'TEXT', 0, None, 0),
#  (17, 'order_06', 'TEXT', 0, None, 0),
#  (18, 'order_05', 'TEXT', 0, None, 0),
#  (19, 'order_04', 'TEXT', 0, None, 0),
#  (20, 'order_03', 'TEXT', 0, None, 0),
#  (21, 'order_02', 'TEXT', 0, None, 0),
#  (22, 'order_01', 'TEXT', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM food_taxonomies
                LIMIT 3
            ;''').fetchall()
# Out:
# [(1,
#   1,
#   357850,
#   '\\Eukaryota\\',
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '\\Eukaryota\\'),
#  (2,
#   1,
#   357850,
#   '\\Viridiplantae\\',
#   2,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '\\Viridiplantae\\',
#   None),
#  (3,
#   1,
#   357850,
#   '\\Streptophyta\\',
#   3,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '\\Streptophyta\\',
#   None,
#   None)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)

# %% [markdown]
# <a id = 'dropcol_compounds'></a>

# %% [markdown]
# ## Dropping columns from compounds table

# %%
compound_columns_to_keep = []

# %%
#for sub in subgroups:
#    if any(generic in sub for generic in generics):
#        generic_subgroups.append(sub)

# %%
for column in compounds.columns:
    if not any(to_drop in column for to_drop in compound_columns_to_drop):
        compound_columns_to_keep.append(column)

# %%
compound_columns_to_keep
# Out:
# ['id', 'name', 'description', 'moldb_formula', 'moldb_id']

# %%
compounds[compound_columns_to_keep]
# Out:
#           id                                               name  \
# 0          1                                    Mulberrofuran P
# 1          4                Cyanidin 3-(6''-acetyl-galactoside)
# 2         13                Cyanidin 3-(6''-succinyl-glucoside)
# 3         14            Pelargonidin 3-(6''-succinyl-glucoside)
# 4         22              Cyanidin 3-O-(6''-acetyl-arabinoside)
# 5         24             Petunidin 3-O-(6''-acetyl-galactoside)
# 6         25                Peonidin 3-(6''-acetyl-galactoside)
# 7         27                Malvidin 3-(6''-acetyl-galactoside)
# 8         31                         Pelargonidin 3-arabinoside
# 9         35             Peonidin 3-(6''-p-coumaroyl-glucoside)
# 10        40                             Delphinidin 3-xyloside
# 11        41            Petunidin 3-(6''-p-coumaroyl-glucoside)
# 12        48                              p-Coumaroyl vitisin A
# 13        52                                          Pinotin A
# 14        55                Malvidin 3-(6''-caffeoyl-glucoside)
# 15        59                 Peonidin 3-(6''-malonyl-glucoside)
# 16        61             Cyanidin 3-O-dimalonyl-laminaribioside
# 17        62             Cyanidin 3-O-(6''-malonyl-arabinoside)
# 18        64  Cyanidin 3-O-(6''-malonyl-3''-glucosyl-glucoside)
# 19        66  Cyanidin 3-O-(2"-xylosyl-6"-(6"'-caffeoyl-gluc...
# 20        69  Cyanidin 3-O-(2"-xylosyl-6"-(6"'-sinapoyl-gluc...
# 21        70  Cyanidin 3-O-(2"-xylosyl-6"-(6"'-feruloyl-gluc...
# 22        72               Delphinidin 3-(6''-malonylglucoside)
# 23        74                           Luteolinidin 3-glucoside
# 24        75                    Delphinidin 3-feruloylglucoside
# 25        78                                       Luteolinidin
# 26        80                                 Pigment A aglycone
# 27        81                                 Pinotin A aglycone
# 28        82                                             Butein
# 29        83                      Phloretin xylosyl-galactoside
# ...      ...                                                ...
# 28741  31488                   2-Methyl-pyrogallol-1-O-sulphate
# 28742  31489                          Caffeic acid 4-O-sulphate
# 28743  31490                   Protocatechuic acid 4-O-sulphate
# 28744  31491                   Protocatechuic acid 3-O-sulphate
# 28745  31492              Hydroxytyrosol 3-O-beta-D-glucuronide
# 28746  31493  (R)-5-(3,5-dihydroxybenzyl)dihydrofuran-2(3H)-...
# 28747  31494                                      Test Compound
# 28748  31496  (R)-5-(3-hydroxybenzyl)dihydrofuran-2(3H)-one ...
# 28749  31497                 3-O-beta-D-Glucuronyl-caffeic acid
# 28750  31498                 4-O-beta-D-Glucuronyl-caffeic acid
# 28751  31499                 4-O-beta-D-Glucuronyl-ferulic acid
# 28752  31500                  3'-O-beta-D-Glucuronyl-hesperetin
# 28753  31501                   7-O-beta-D-Glucuronyl-hesperetin
# 28754  31503               4-O-beta-D-Glucuronyl-hydroxytyrosol
# 28755  31504                  4'-O-beta-D-Glucuronyl-naringenin
# 28756  31505                   7-O-beta-D-Glucuronyl-naringenin
# 28757  31506              4-O-beta-D-Glucuronyl-p-coumaric acid
# 28758  31507  (Rac)-5-(3,5-dihydroxybenzyl)dihydrofuran-2(3H...
# 28759  31508      (R)-5-(3-hydroxybenzyl)dihydrofuran-2(3H)-one
# 28760  31509      (R)-5-(4-hydroxybenzyl)dihydrofuran-2(3H)-one
# 28761  31510  (R)-5-(3,4-dihydroxybenzyl)dihydrofuran-2(3H)-...
# 28762  31511  (R)-5-(3,4-dihydroxybenzyl)dihydrofuran-2(3H)-one
# 28763  31512  (R)-5-(3,5-dihydroxybenzyl)dihydrofuran-2(3H)-one
# 28764  31513  (Rac)-5-(3,4,5-trihydroxybenzyl)dihydrofuran-2...
# 28765  31521                             Quercetin-4'-O-sulfate
# 28766  31523                          Quercetin 3-O-glucuronide
# 28767  31524                         3Û_-O-methyl(epi)catechin
# 28768  31525                         4Û_-O-methyl(epi)catechin
# 28769  31526                       (Epi)catechin-3Û_-O-sulfate
# 28770  31527                       (Epi)catechin-4Û_-O-sulfate
#
#                                              description moldb_formula  \
# 0          Constit. of Morus alba (white mulberry) [CCD]      C34H22O9
# 1          Constit. of the leaves of Nymphaea alba [CCD]     C23H23O12
# 2                 Constit. of Phragmites australis [CCD]     C25H25O14
# 3                                                            C25H25O13
# 4      A polyphenol compound found in foods of plant ...     C22H21O11
# 5                                                            C24H25O13
# 6                                                            C24H25O12
# 7                                                            C25H27O13
# 8                                                             C20H19O9
# 9                                                            C31H29O13
# 10                                                           C20H19O11
# 11                                                           C31H29O14
# 12     A polyphenol compound found in foods of plant ...     C35H31O16
# 13              Isol. from red wine incl. Pinotage (CCD)     C31H29O14
# 14                                                           C32H31O15
# 15     A polyphenol compound found in foods of plant ...     C25H25O14
# 16     A polyphenol compound found in foods of plant ...     C33H35O22
# 17     A polyphenol compound found in foods of plant ...     C23H21O13
# 18                                                           C30H33O19
# 19     A polyphenol compound found in foods of plant ...     C41H45O23
# 20     A polyphenol compound found in foods of plant ...     C43H49O24
# 21     A polyphenol compound found in foods of plant ...     C42H47O23
# 22     A polyphenol compound found in foods of plant ...     C24H23O15
# 23     A polyphenol compound found in foods of plant ...     C21H21O10
# 24                                                           C31H29O15
# 25     Luteolinidin is a chemical compound belonging ...      C15H11O5
# 26     A polyphenol compound found in foods of plant ...      C25H19O8
# 27     A polyphenol compound found in foods of plant ...      C25H19O9
# 28                                                            C15H12O5
# 29     A polyphenol compound found in foods of plant ...     C26H32O14
# ...                                                  ...           ...
# 28741                                                          C7H8O6S
# 28742                                                          C9H8O7S
# 28743                                                          C7H6O7S
# 28744                                                          C7H6O7S
# 28745                                                         C14H18O9
# 28746                                                        C17H20O10
# 28747                                                          C13H16O
# 28748                                                        C17H20O10
# 28749                                                        C15H16O10
# 28750                                                        C15H16O10
# 28751                                                        C16H18O10
# 28752                                                        C22H22O12
# 28753                                                        C22H22O12
# 28754                                                         C14H18O9
# 28755                                                        C21H20O11
# 28756                                                        C21H20O11
# 28757                                                         C15H16O9
# 28758
# 28759                                                         C11H12O3
# 28760                                                         C11H12O3
# 28761
# 28762                                                         C11H12O4
# 28763                                                         C11H12O4
# 28764                                                         C11H12O5
# 28765                                                       C15H10O10S
# 28766
# 28767                                                         C16H12O7
# 28768                                                         C16H18O7
# 28769                                                        C15H14O9S
# 28770                                                        C15H14O9S
#
#       moldb_id
# 0        31941
# 1        80753
# 2        80754
# 3        80799
# 4        80755
# 5        27777
# 6        27774
# 7        27770
# 8        80800
# 9        27776
# 10       27760
# 11       27779
# 12       27771
# 13       79407
# 14       27769
# 15       80893
# 16       80759
# 17       80757
# 18       80760
# 19       80762
# 20       80764
# 21       80765
# 22       27759
# 23       39609
# 24       27761
# 25       41515
# 26       40769
# 27       41641
# 28       41513
# 29       40634
# ...        ...
# 28741
# 28742
# 28743
# 28744
# 28745
# 28746
# 28747
# 28748
# 28749
# 28750
# 28751
# 28752
# 28753
# 28754
# 28755
# 28756
# 28757
# 28758
# 28759
# 28760
# 28761
# 28762
# 28763
# 28764
# 28765
# 28766
# 28767
# 28768
# 28769
# 28770
#
# [28771 rows x 5 columns]

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info()
;''',).fetchall()

# %%
#Create a new  table
cur.execute('''CREATE TABLE compounds_copy
                (id INTEGER PRIMARY KEY, name TEXT, description TEXT,
                moldb_formula TEXT, moldb_id INTEGER)
            ;''')

#Look at columns in  table
cur.execute('''PRAGMA table_info(compounds_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'description', 'TEXT', 0, None, 0),
#  (3, 'moldb_formula', 'TEXT', 0, None, 0),
#  (4, 'moldb_id', 'INTEGER', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO compounds_copy
                    (id, name, description, moldb_formula, moldb_id)
                SELECT id, name, description, moldb_formula, moldb_id
                FROM compounds
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(compounds_copy)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'description', 'TEXT', 0, None, 0),
#  (3, 'moldb_formula', 'TEXT', 0, None, 0),
#  (4, 'moldb_id', 'INTEGER', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM _copy
                LIMIT 5
            ;''').fetchall()

# %%
#Delete the old table
cur.execute('''DROP TABLE compounds;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE compounds_copy
                RENAME TO compounds
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('foods',),
#  ('enzymes',),
#  ('health_effects',),
#  ('flavors',),
#  ('pathways',),
#  ('food_taxonomies',),
#  ('compounds',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(compounds)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 0, None, 0),
#  (2, 'description', 'TEXT', 0, None, 0),
#  (3, 'moldb_formula', 'TEXT', 0, None, 0),
#  (4, 'moldb_id', 'INTEGER', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %%
connection.close()

# %%
compounds = pd.read_sql_query('''SELECT * 
                                    FROM compounds''', engine)
# Out:
# 2019-03-16 12:28:30,631 INFO sqlalchemy.engine.base.Engine SELECT *
#                                     FROM compounds
# INFO:sqlalchemy.engine.base.Engine:SELECT *
#                                     FROM compounds
# 2019-03-16 12:28:30,631 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
compounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28771 entries, 0 to 28770
# Data columns (total 5 columns):
# id               28771 non-null int64
# name             28771 non-null object
# description      28771 non-null object
# moldb_formula    28771 non-null object
# moldb_id         28771 non-null object
# dtypes: int64(1), object(4)
# memory usage: 1.1+ MB

# %%
compounds[compounds['moldb_id'] != ''].shape[0]
# Out:
# 24399

# %% [markdown]
# [(Back to top)](#top)
# ## Dropping columns from compounds_enzymes table

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(compounds_enzymes)
;''',).fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'compound_id', 'INTEGER', 0, None, 0),
#  (2, 'enzyme_id', 'INTEGER', 0, None, 0)]

# %%
#Create a new  table
cur.execute('''CREATE TABLE compounds_enzymes_copy
                (compound_id INTEGER, enzyme_id INTEGER,
                FOREIGN KEY(compound_id) REFERENCES compounds(id),
                FOREIGN KEY(enzyme_id) REFERENCES enzymes(id))
            ;''')

#Look at columns in  table
cur.execute('''PRAGMA table_info(compounds_enzymes_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'enzyme_id', 'INTEGER', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO compounds_enzymes_copy
                    (compound_id, enzyme_id)
                SELECT compound_id, enzyme_id
                FROM compounds_enzymes
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(compounds_enzymes_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'enzyme_id', 'INTEGER', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM compounds_enzymes_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(362, 1), (362, 2), (362, 3), (362, 4), (362, 5)]

# %%
#Delete the old table
cur.execute('''DROP TABLE compounds_enzymes;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE compounds_enzymes_copy
                RENAME TO compounds_enzymes
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('foods',),
#  ('enzymes',),
#  ('health_effects',),
#  ('flavors',),
#  ('pathways',),
#  ('compounds',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('food_taxonomies',),
#  ('compounds_enzymes',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(compounds_enzymes)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'enzyme_id', 'INTEGER', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %%
connection.close()

# %% [markdown]
# [(Back to top)](#top)
# ## Dropping columns from compounds_flavors table

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(compounds_flavors)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'compound_id', '', 0, None, 0),
#  (2, 'flavor_id', '', 0, None, 0),
#  (3, 'citations', '', 0, None, 0),
#  (4, 'created_at', '', 0, None, 0),
#  (5, 'updated_at', '', 0, None, 0),
#  (6, 'creator_id', '', 0, None, 0),
#  (7, 'updater_id', '', 0, None, 0),
#  (8, 'source_id', '', 0, None, 0),
#  (9, 'source_type', '', 0, None, 0)]

# %%
#Create a new  table
cur.execute('''CREATE TABLE compounds_flavors_copy
                (compound_id INTEGER, flavor_id INTEGER,
                FOREIGN KEY(compound_id) REFERENCES compounds(id),
                FOREIGN KEY(flavor_id) REFERENCES flavors(id))
            ;''')

#Look at columns in  table
cur.execute('''PRAGMA table_info(compounds_flavors_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'flavor_id', 'INTEGER', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO compounds_flavors_copy
                    (compound_id, flavor_id)
                SELECT compound_id, flavor_id
                FROM compounds_flavors
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(compounds_flavors_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'flavor_id', 'INTEGER', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM compounds_flavors_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(11947, 159), (8298, 213), (8298, 156), (11889, 231), (11889, 166)]

# %%
#Delete the old table
cur.execute('''DROP TABLE compounds_flavors;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE compounds_flavors_copy
                RENAME TO compounds_flavors
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compounds_health_effects',),
#  ('compounds_pathways',),
#  ('foods',),
#  ('enzymes',),
#  ('health_effects',),
#  ('flavors',),
#  ('pathways',),
#  ('food_taxonomies',),
#  ('compounds',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(compounds_flavors)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'flavor_id', 'INTEGER', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)
# ## Dropping columns from compounds_health_effects table

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(compounds_health_effects )
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'compound_id', '', 0, None, 0),
#  (2, 'health_effect_id', '', 0, None, 0),
#  (3, 'orig_health_effect_name', '', 0, None, 0),
#  (4, 'orig_compound_name', '', 0, None, 0),
#  (5, 'orig_citation', '', 0, None, 0),
#  (6, 'citation', '', 0, None, 0),
#  (7, 'citation_type', '', 0, None, 0),
#  (8, 'created_at', '', 0, None, 0),
#  (9, 'updated_at', '', 0, None, 0),
#  (10, 'creator_id', '', 0, None, 0),
#  (11, 'updater_id', '', 0, None, 0),
#  (12, 'source_id', '', 0, None, 0),
#  (13, 'source_type', '', 0, None, 0)]

# %%
#Create a new  table
cur.execute('''CREATE TABLE compounds_health_effects_copy
                (compound_id INTEGER, health_effect_id INTEGER,
                FOREIGN KEY(compound_id) REFERENCES compounds(id),
                FOREIGN KEY(health_effect_id) REFERENCES health_effects(id))
            ;''')

#Look at columns in  table
cur.execute('''PRAGMA table_info(compounds_health_effects_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'health_effect_id', 'INTEGER', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO compounds_health_effects_copy
                    (compound_id, health_effect_id)
                SELECT compound_id, health_effect_id
                FROM compounds_health_effects 
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(compounds_health_effects_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'health_effect_id', 'INTEGER', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM compounds_health_effects_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(453, 1), (2100, 1), (9030, 2), (13577, 2), (14619, 2)]

# %%
#Delete the old table
cur.execute('''DROP TABLE compounds_health_effects;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE compounds_health_effects_copy
                RENAME TO compounds_health_effects 
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('compounds_pathways',),
#  ('foods',),
#  ('enzymes',),
#  ('health_effects',),
#  ('flavors',),
#  ('pathways',),
#  ('food_taxonomies',),
#  ('compounds',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(compounds_health_effects )
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'health_effect_id', 'INTEGER', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)
# ## Dropping columns from compounds_pathways table

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info(compounds_pathways)
;''',).fetchall()
# Out:
# [(0, 'id', '', 0, None, 0),
#  (1, 'compound_id', '', 0, None, 0),
#  (2, 'pathway_id', '', 0, None, 0),
#  (3, 'creator_id', '', 0, None, 0),
#  (4, 'updater_id', '', 0, None, 0),
#  (5, 'created_at', '', 0, None, 0),
#  (6, 'updated_at', '', 0, None, 0)]

# %%
#Create a new  table
cur.execute('''CREATE TABLE compounds_pathways_copy
                (compound_id INTEGER, pathway_id INTEGER,
                FOREIGN KEY(compound_id) REFERENCES compounds(id),
                FOREIGN KEY(pathway_id) REFERENCES pathways(id))
            ;''')

#Look at columns in  table
cur.execute('''PRAGMA table_info(compounds_pathways_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'pathway_id', 'INTEGER', 0, None, 0)]

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO compounds_pathways_copy
                    (compound_id, pathway_id)
                SELECT compound_id, pathway_id
                FROM compounds_pathways
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(compounds_pathways_copy)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'pathway_id', 'INTEGER', 0, None, 0)]

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM compounds_pathways_copy
                LIMIT 5
            ;''').fetchall()
# Out:
# [(316, 1), (362, 2), (374, 3), (374, 4), (433, 1)]

# %%
#Delete the old table
cur.execute('''DROP TABLE compounds_pathways;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE compounds_pathways_copy
                RENAME TO compounds_pathways
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()
# Out:
# [('foods',),
#  ('enzymes',),
#  ('health_effects',),
#  ('flavors',),
#  ('pathways',),
#  ('food_taxonomies',),
#  ('compounds',),
#  ('compounds_enzymes',),
#  ('compounds_flavors',),
#  ('compounds_health_effects',),
#  ('compounds_pathways',)]

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info(compounds_pathways)
;''',).fetchall()
# Out:
# [(0, 'compound_id', 'INTEGER', 0, None, 0),
#  (1, 'pathway_id', 'INTEGER', 0, None, 0)]

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# [(Back to top)](#top)
# ## Dropping columns from [    ] table

# %%
# connect to db
connection = sqlite3.connect('foodb.db')
cur = connection.cursor()

# %%
#Look at columns in enzymes table
cur.execute('''PRAGMA table_info()
;''',).fetchall()

# %%
#Create a new  table
cur.execute('''CREATE TABLE e_copy
                (id INTEGER PRIMARY KEY, name TEXT, gene_name TEXT, 
                uniprot_id TEXT)
            ;''')

#Look at columns in  table
cur.execute('''PRAGMA table_info(_copy)
;''',).fetchall()

# %%
#Insert values into columns of new table
cur.execute('''INSERT INTO _copy
                    (id, name, gene_name, uniprot_id)
                SELECT id, name, gene_name, uniprot_id
                FROM 
            ;''')
#Check data types of new table
#Works before commit

cur.execute('''PRAGMA table_info(_copy)
;''',).fetchall()

# %%
#Check that columns were populated from old table
#This function works without committing 
cur.execute('''SELECT *
                FROM _copy
                LIMIT 5
            ;''').fetchall()

# %%
#Delete the old table
cur.execute('''DROP TABLE ;''')

#Rename new table to enzymes
cur.execute('''ALTER TABLE _copy
                RENAME TO 
                ;''')
#Check list of tables in database
cur.execute('''SELECT name
                FROM sqlite_master 
                WHERE type ='table' 
                    AND name NOT LIKE 'sqlite_%'
            ;''').fetchall()

# %%
#Check columns of new table
cur.execute('''PRAGMA table_info()
;''',).fetchall()

# %%
# Save (commit) the changes
connection.commit()

# %% [markdown]
# <a id = 'dropping_tables'></a>

# %% [markdown]
# [(Back to top)](#top)
# # Dropping whole tables

# %%
cur.execute('''DROP TABLE nutrients;''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-122-378e664d6118> in <module>()
# ----> 1 cur.execute('''DROP TABLE nutrients;''')
#       2 cur.execute('''DROP TABLE [references];''')
#
# OperationalError: no such table: nutrients

# %%
cur.execute('''DROP TABLE [references];''')

# %%
# Save (commit) the changes
connection.commit()

# %%
connection.close()

# %%
#Drop compound-related tables
cur.execute('''DROP TABLE foodcomex_compound_providers;''')
cur.execute('''DROP TABLE foodcomex_compounds;''')
cur.execute('''DROP TABLE compound_alternate_parents;''')
cur.execute('''DROP TABLE compound_external_descriptors;''')
cur.execute('''DROP TABLE compound_substituents;''')
cur.execute('''DROP TABLE compound_synonyms;''')
connection.commit()

# %%
connection.close()

# %%
###############################################################################################

# %%
#This encoding works with Windows.
foods = pd.read_csv('foods.csv', encoding = "ISO-8859-1")

# %%
foods.head()

# %%
compounds = pd.read_csv('compounds.csv', encoding = "ISO-8859-1")

# %%
compounds_flavors = pd.read_csv('compounds_flavors.csv', encoding = "ISO-8859-1")

# %%
foodcomex_compounds = pd.read_csv('foodcomex_compounds.csv', encoding = "ISO-8859-1")
